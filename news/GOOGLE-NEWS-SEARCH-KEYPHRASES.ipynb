# %%
from pandas import json_normalize
import pandas as pd
import requests
import feedparser
from urllib.parse import urlparse, urljoin, quote
import time
import datetime
# for web scraping
from IPython.display import HTML
from bs4 import BeautifulSoup

import string

## adding some cleaning functions
transtable = str.maketrans(dict.fromkeys(string.punctuation))


def to_string(s):
    """
    takes input s and returns a string type and encoding if necessary
    """
    try:
        return str(s)
    except:
        # Change the encoding type if needed
        return s.encode('utf-8')


def unicode_to_ascii(s):
    """
    input: string
    output: string ascii
    """
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )


def strip_punctuation(input_string):
    """
    cleans string by stripping punctuation
    """

    return input_string.translate(transtable)

# Define the start date for the search - provided as 1/1/2020
start_date = datetime.datetime(2020, 1, 1)

# Get today's date
today_date = datetime.datetime.today()

# Calculate the difference in days
days_difference = (today_date - start_date).days

print(f"Number of days from 1/1/2020 to today: {days_difference} days")
# Out:
# Number of days from 1/1/2020 to today: 1685 days

# %%
# two locations of interest - these are the search word comibinations
search_keywords_combinations = {
    "Fort Fairfield": ["LPOE", "border", "port", "crossing", "customs", "GSA", "general services administration"],
    "San Luis":  ["LPOE", "border", "port", "crossing", "garita", "GSA", "general services administration"]
                               }

# %%
def parse_feeds_df(rss_url):
    """once given url for the rss"""
    
    #Read feed xml data 
    news_feed = feedparser.parse(rss_url) 

    #Flatten data
    df_news_feed=json_normalize(news_feed.entries)
    
    # returns dataframe of news feed entries
    return df_news_feed

# %%
# "https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22LPOE%22%20when%3A1685d&hl=en-US&gl=US&ceid=US%3Aen"

query_list = []
for k, val in search_keywords_combinations.items():
    for v in val:
        query_ = f'"{k}" AND "{v}" when:{days_difference}d'
        query_list.append(query_)
        
query_list
# Out:
# ['"Fort Fairfield" AND "LPOE" when:1685d',
#  '"Fort Fairfield" AND "border" when:1685d',
#  '"Fort Fairfield" AND "port" when:1685d',
#  '"Fort Fairfield" AND "crossing" when:1685d',
#  '"Fort Fairfield" AND "customs" when:1685d',
#  '"Fort Fairfield" AND "GSA" when:1685d',
#  '"Fort Fairfield" AND "general services administration" when:1685d',
#  '"San Luis" AND "LPOE" when:1685d',
#  '"San Luis" AND "border" when:1685d',
#  '"San Luis" AND "port" when:1685d',
#  '"San Luis" AND "crossing" when:1685d',
#  '"San Luis" AND "garita" when:1685d',
#  '"San Luis" AND "GSA" when:1685d',
#  '"San Luis" AND "general services administration" when:1685d']

# %%
# empty list of dataframes
list_of_dfs = []

for q in query_list:
    rss_url ='https://news.google.com/rss/search?q=' + quote(q)
    search_url = 'https://news.google.com/search?q=' + quote(q)
    print(search_url)
    df_temp = parse_feeds_df(rss_url)
    df_temp["query"] = q
    q_simple = q.split(" when")[0]
    print(f"{q_simple}: {df_temp.shape[0]} hits")
    list_of_dfs.append(df_temp)
    time.sleep(20)
# Out:
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22LPOE%22%20when%3A1685d
# "Fort Fairfield" AND "LPOE": 6 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22border%22%20when%3A1685d
# "Fort Fairfield" AND "border": 16 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22port%22%20when%3A1685d
# "Fort Fairfield" AND "port": 9 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22crossing%22%20when%3A1685d
# "Fort Fairfield" AND "crossing": 8 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22customs%22%20when%3A1685d
# "Fort Fairfield" AND "customs": 9 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22GSA%22%20when%3A1685d
# "Fort Fairfield" AND "GSA": 10 hits
# https://news.google.com/search?q=%22Fort%20Fairfield%22%20AND%20%22general%20services%20administration%22%20when%3A1685d
# "Fort Fairfield" AND "general services administration": 9 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22LPOE%22%20when%3A1685d
# "San Luis" AND "LPOE": 10 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22border%22%20when%3A1685d
# "San Luis" AND "border": 100 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22port%22%20when%3A1685d
# "San Luis" AND "port": 100 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22crossing%22%20when%3A1685d
# "San Luis" AND "crossing": 54 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22garita%22%20when%3A1685d
# "San Luis" AND "garita": 8 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22GSA%22%20when%3A1685d
# "San Luis" AND "GSA": 15 hits
# https://news.google.com/search?q=%22San%20Luis%22%20AND%20%22general%20services%20administration%22%20when%3A1685d
# "San Luis" AND "general services administration": 10 hits

# %%
df_full_open_scrape = pd.concat(list_of_dfs).reset_index(drop=True)

print(df_full_open_scrape.shape[0])
# Out:
# 364

# %%
# 297 unique articles found

# number of unique articles - 297
print(df_full_open_scrape.id.nunique())
# Out:
# 259

# %%
df_full_open_scrape.head()
# Out:
#                                                title  \
# 0  Meetings will be held this week to discuss new...
# 1  Meeting on Fort Fairfield port of entry is Tue...
# 2  Fort Fairfield residents voice concerns about ...
# 3  Discussing the New Port of Entries in the Coun...
# 4  Residents’ Reply to Possible Closures of Port ...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  https://news.google.com/rss/articles/CBMiuAFBV...
# 1  https://news.google.com/rss/articles/CBMilgFBV...
# 2  https://news.google.com/rss/articles/CBMixAFBV...
# 3  https://news.google.com/rss/articles/CBMieEFVX...
# 4  https://news.google.com/rss/articles/CBMikgFBV...
#
#                                                   id  guidislink  \
# 0  CBMiuAFBVV95cUxNZEZkRmc2VlpvNHlxVWF4cUZjNzd5S2...       False
# 1  CBMilgFBVV95cUxOc2tpUGxKd3doSERTdVA1UDhWV1VpOG...       False
# 2  CBMixAFBVV95cUxNNnBJeHBreVhhU082dnRGRml6b3NtS2...       False
# 3  CBMieEFVX3lxTE5NYkdFZGdncjZVYnA0R1pPdUo4NUQ1VG...       False
# 4  CBMikgFBVV95cUxQZEVFQ21rc1k4SF92OGRlbTJSRUNTbW...       False
#
#                        published                      published_parsed  \
# 0  Tue, 30 Jul 2024 07:00:00 GMT     (2024, 7, 30, 7, 0, 0, 1, 212, 0)
# 1  Mon, 29 Jul 2024 14:14:37 GMT  (2024, 7, 29, 14, 14, 37, 0, 211, 0)
# 2  Wed, 31 Jul 2024 20:58:28 GMT  (2024, 7, 31, 20, 58, 28, 2, 213, 0)
# 3  Wed, 31 Jul 2024 07:00:00 GMT     (2024, 7, 31, 7, 0, 0, 2, 213, 0)
# 4  Thu, 01 Aug 2024 07:00:00 GMT      (2024, 8, 1, 7, 0, 0, 3, 214, 0)
#
#                                              summary title_detail.type  \
# 0  <a href="https://news.google.com/rss/articles/...        text/plain
# 1  <a href="https://news.google.com/rss/articles/...        text/plain
# 2  <a href="https://news.google.com/rss/articles/...        text/plain
# 3  <a href="https://news.google.com/rss/articles/...        text/plain
# 4  <a href="https://news.google.com/rss/articles/...        text/plain
#
#   title_detail.language                                  title_detail.base  \
# 0                  None  https://news.google.com/rss/search?q=%22Fort+F...
# 1                  None  https://news.google.com/rss/search?q=%22Fort+F...
# 2                  None  https://news.google.com/rss/search?q=%22Fort+F...
# 3                  None  https://news.google.com/rss/search?q=%22Fort+F...
# 4                  None  https://news.google.com/rss/search?q=%22Fort+F...
#
#                                   title_detail.value summary_detail.type  \
# 0  Meetings will be held this week to discuss new...           text/html
# 1  Meeting on Fort Fairfield port of entry is Tue...           text/html
# 2  Fort Fairfield residents voice concerns about ...           text/html
# 3  Discussing the New Port of Entries in the Coun...           text/html
# 4  Residents’ Reply to Possible Closures of Port ...           text/html
#
#   summary_detail.language                                summary_detail.base  \
# 0                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 1                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 2                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 3                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 4                    None  https://news.google.com/rss/search?q=%22Fort+F...
#
#                                 summary_detail.value  \
# 0  <a href="https://news.google.com/rss/articles/...
# 1  <a href="https://news.google.com/rss/articles/...
# 2  <a href="https://news.google.com/rss/articles/...
# 3  <a href="https://news.google.com/rss/articles/...
# 4  <a href="https://news.google.com/rss/articles/...
#
#                        source.href       source.title  \
# 0           https://www.wagmtv.com               WAGM
# 1             https://thecounty.me         The County
# 2  https://www.bangordailynews.com  Bangor Daily News
# 3           https://www.wagmtv.com               WAGM
# 4           https://www.wagmtv.com               WAGM
#
#                                     query
# 0  "Fort Fairfield" AND "LPOE" when:1685d
# 1  "Fort Fairfield" AND "LPOE" when:1685d
# 2  "Fort Fairfield" AND "LPOE" when:1685d
# 3  "Fort Fairfield" AND "LPOE" when:1685d
# 4  "Fort Fairfield" AND "LPOE" when:1685d

# %%
df_full_open_scrape.iloc[0]
# Out:
# title                      Meetings will be held this week to discuss new...
# links                      [{'rel': 'alternate', 'type': 'text/html', 'hr...
# link                       https://news.google.com/rss/articles/CBMiuAFBV...
# id                         CBMiuAFBVV95cUxNZEZkRmc2VlpvNHlxVWF4cUZjNzd5S2...
# guidislink                                                             False
# published                                      Tue, 30 Jul 2024 07:00:00 GMT
# published_parsed                           (2024, 7, 30, 7, 0, 0, 1, 212, 0)
# summary                    <a href="https://news.google.com/rss/articles/...
# title_detail.type                                                 text/plain
# title_detail.language                                                   None
# title_detail.base          https://news.google.com/rss/search?q=%22Fort+F...
# title_detail.value         Meetings will be held this week to discuss new...
# summary_detail.type                                                text/html
# summary_detail.language                                                 None
# summary_detail.base        https://news.google.com/rss/search?q=%22Fort+F...
# summary_detail.value       <a href="https://news.google.com/rss/articles/...
# source.href                                           https://www.wagmtv.com
# source.title                                                            WAGM
# query                                 "Fort Fairfield" AND "LPOE" when:1685d
# Name: 0, dtype: object

# %%
id2query = df_full_open_scrape.groupby('id', as_index=False)["query"].agg(list)
id2query_dict = {}
for i, row in id2query.iterrows():
    id2query_dict[row["id"]] = row["query"]

# %%
#! pip install google-api-python-client


df_full_open_scrape["link"].tolist()[1]
# Out:
# 'https://news.google.com/rss/articles/CBMilgFBVV95cUxOc2tpUGxKd3doSERTdVA1UDhWV1VpOGZwVko5R3FFMVZBMThZNXd6Zmh5TE5oaE1zaGpVR1FJTGNVQ0RaVjRyOVdPYmNra1E5UjduQkNDUklSTTFxblY0dzhNaFdIX1R1T2d5a0k3SmxPRUxBa0p4RWdybEVieWNmWVh4N2NodFN6QXJkdUZrUG5iazVBSFE?oc=5'

# %%
query_list[0]
# Out:
# '"Fort Fairfield" AND "LPOE" when:1685d'

# %%
new_df_full_open_scrape = df_full_open_scrape.drop_duplicates("id")
new_df_full_open_scrape
# Out:
#                                                  title  \
# 0    Meetings will be held this week to discuss new...
# 1    Meeting on Fort Fairfield port of entry is Tue...
# 2    Fort Fairfield residents voice concerns about ...
# 3    Discussing the New Port of Entries in the Coun...
# 4    Residents’ Reply to Possible Closures of Port ...
# ..                                                 ...
# 341  Paso Robles GSA approves county as contracting...
# 345  WATCH: Kelly Gets Updates on Arizona Port of E...
# 346  Hensel Phelps Awarded $174M GSA Contract for C...
# 347  GSA to Spend $3.4 Billion to Update 26 Land Po...
# 349  A Water War Is Underway in Santa Barbara Count...
#
#                                                  links  \
# 0    [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1    [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2    [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3    [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4    [{'rel': 'alternate', 'type': 'text/html', 'hr...
# ..                                                 ...
# 341  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 345  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 346  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 347  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 349  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                   link  \
# 0    https://news.google.com/rss/articles/CBMiuAFBV...
# 1    https://news.google.com/rss/articles/CBMilgFBV...
# 2    https://news.google.com/rss/articles/CBMixAFBV...
# 3    https://news.google.com/rss/articles/CBMieEFVX...
# 4    https://news.google.com/rss/articles/CBMikgFBV...
# ..                                                 ...
# 341  https://news.google.com/rss/articles/CBMi6gFBV...
# 345  https://news.google.com/rss/articles/CBMisgFBV...
# 346  https://news.google.com/rss/articles/CBMivwFBV...
# 347  https://news.google.com/rss/articles/CBMihgFBV...
# 349  https://news.google.com/rss/articles/CBMipgFBV...
#
#                                                     id  guidislink  \
# 0    CBMiuAFBVV95cUxNZEZkRmc2VlpvNHlxVWF4cUZjNzd5S2...       False
# 1    CBMilgFBVV95cUxOc2tpUGxKd3doSERTdVA1UDhWV1VpOG...       False
# 2    CBMixAFBVV95cUxNNnBJeHBreVhhU082dnRGRml6b3NtS2...       False
# 3    CBMieEFVX3lxTE5NYkdFZGdncjZVYnA0R1pPdUo4NUQ1VG...       False
# 4    CBMikgFBVV95cUxQZEVFQ21rc1k4SF92OGRlbTJSRUNTbW...       False
# ..                                                 ...         ...
# 341  CBMi6gFBVV95cUxNUWJYWks3WUNHNDQzR0xGQTRrdlVuX0...       False
# 345  CBMisgFBVV95cUxQWFZ5UE9hbUVhY0dKZmxfRUNDQmI3Nz...       False
# 346  CBMivwFBVV95cUxNbVBYcVo1WjBYMVpzcFVZb1cwZXc5aT...       False
# 347  CBMihgFBVV95cUxNRHZhbVpCREJmb0E2VG9uRFpjWkkwVk...       False
# 349  CBMipgFBVV95cUxPcEhaZjJ4XzJ5Z0tOcVZMMElkNmctU3...       False
#
#                          published                      published_parsed  \
# 0    Tue, 30 Jul 2024 07:00:00 GMT     (2024, 7, 30, 7, 0, 0, 1, 212, 0)
# 1    Mon, 29 Jul 2024 14:14:37 GMT  (2024, 7, 29, 14, 14, 37, 0, 211, 0)
# 2    Wed, 31 Jul 2024 20:58:28 GMT  (2024, 7, 31, 20, 58, 28, 2, 213, 0)
# 3    Wed, 31 Jul 2024 07:00:00 GMT     (2024, 7, 31, 7, 0, 0, 2, 213, 0)
# 4    Thu, 01 Aug 2024 07:00:00 GMT      (2024, 8, 1, 7, 0, 0, 3, 214, 0)
# ..                             ...                                   ...
# 341  Wed, 17 Jan 2024 08:00:00 GMT      (2024, 1, 17, 8, 0, 0, 2, 17, 0)
# 345  Wed, 10 Jul 2024 07:00:00 GMT     (2024, 7, 10, 7, 0, 0, 2, 192, 0)
# 346  Mon, 29 Jul 2024 07:00:00 GMT     (2024, 7, 29, 7, 0, 0, 0, 211, 0)
# 347  Wed, 14 Dec 2022 08:00:00 GMT    (2022, 12, 14, 8, 0, 0, 2, 348, 0)
# 349  Thu, 06 Jul 2023 07:00:00 GMT      (2023, 7, 6, 7, 0, 0, 3, 187, 0)
#
#                                                summary title_detail.type  \
# 0    <a href="https://news.google.com/rss/articles/...        text/plain
# 1    <a href="https://news.google.com/rss/articles/...        text/plain
# 2    <a href="https://news.google.com/rss/articles/...        text/plain
# 3    <a href="https://news.google.com/rss/articles/...        text/plain
# 4    <a href="https://news.google.com/rss/articles/...        text/plain
# ..                                                 ...               ...
# 341  <a href="https://news.google.com/rss/articles/...        text/plain
# 345  <a href="https://news.google.com/rss/articles/...        text/plain
# 346  <a href="https://news.google.com/rss/articles/...        text/plain
# 347  <a href="https://news.google.com/rss/articles/...        text/plain
# 349  <a href="https://news.google.com/rss/articles/...        text/plain
#
#     title_detail.language                                  title_detail.base  \
# 0                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 1                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 2                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 3                    None  https://news.google.com/rss/search?q=%22Fort+F...
# 4                    None  https://news.google.com/rss/search?q=%22Fort+F...
# ..                    ...                                                ...
# 341                  None  https://news.google.com/rss/search?q=%22San+Lu...
# 345                  None  https://news.google.com/rss/search?q=%22San+Lu...
# 346                  None  https://news.google.com/rss/search?q=%22San+Lu...
# 347                  None  https://news.google.com/rss/search?q=%22San+Lu...
# 349                  None  https://news.google.com/rss/search?q=%22San+Lu...
#
#                                     title_detail.value summary_detail.type  \
# 0    Meetings will be held this week to discuss new...           text/html
# 1    Meeting on Fort Fairfield port of entry is Tue...           text/html
# 2    Fort Fairfield residents voice concerns about ...           text/html
# 3    Discussing the New Port of Entries in the Coun...           text/html
# 4    Residents’ Reply to Possible Closures of Port ...           text/html
# ..                                                 ...                 ...
# 341  Paso Robles GSA approves county as contracting...           text/html
# 345  WATCH: Kelly Gets Updates on Arizona Port of E...           text/html
# 346  Hensel Phelps Awarded $174M GSA Contract for C...           text/html
# 347  GSA to Spend $3.4 Billion to Update 26 Land Po...           text/html
# 349  A Water War Is Underway in Santa Barbara Count...           text/html
#
#     summary_detail.language  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 341                    None
# 345                    None
# 346                    None
# 347                    None
# 349                    None
#
#                                    summary_detail.base  \
# 0    https://news.google.com/rss/search?q=%22Fort+F...
# 1    https://news.google.com/rss/search?q=%22Fort+F...
# 2    https://news.google.com/rss/search?q=%22Fort+F...
# 3    https://news.google.com/rss/search?q=%22Fort+F...
# 4    https://news.google.com/rss/search?q=%22Fort+F...
# ..                                                 ...
# 341  https://news.google.com/rss/search?q=%22San+Lu...
# 345  https://news.google.com/rss/search?q=%22San+Lu...
# 346  https://news.google.com/rss/search?q=%22San+Lu...
# 347  https://news.google.com/rss/search?q=%22San+Lu...
# 349  https://news.google.com/rss/search?q=%22San+Lu...
#
#                                   summary_detail.value  \
# 0    <a href="https://news.google.com/rss/articles/...
# 1    <a href="https://news.google.com/rss/articles/...
# 2    <a href="https://news.google.com/rss/articles/...
# 3    <a href="https://news.google.com/rss/articles/...
# 4    <a href="https://news.google.com/rss/articles/...
# ..                                                 ...
# 341  <a href="https://news.google.com/rss/articles/...
# 345  <a href="https://news.google.com/rss/articles/...
# 346  <a href="https://news.google.com/rss/articles/...
# 347  <a href="https://news.google.com/rss/articles/...
# 349  <a href="https://news.google.com/rss/articles/...
#
#                          source.href               source.title  \
# 0             https://www.wagmtv.com                       WAGM
# 1               https://thecounty.me                 The County
# 2    https://www.bangordailynews.com          Bangor Daily News
# 3             https://www.wagmtv.com                       WAGM
# 4             https://www.wagmtv.com                       WAGM
# ..                               ...                        ...
# 341      https://pasoroblespress.com      The Paso Robles Press
# 345     https://www.kelly.senate.gov         Senator Mark Kelly
# 346       https://www.govconwire.com                GovCon Wire
# 347           https://www.ttnews.com           Transport Topics
# 349      https://www.independent.com  Santa Barbara Independent
#
#                                       query
# 0    "Fort Fairfield" AND "LPOE" when:1685d
# 1    "Fort Fairfield" AND "LPOE" when:1685d
# 2    "Fort Fairfield" AND "LPOE" when:1685d
# 3    "Fort Fairfield" AND "LPOE" when:1685d
# 4    "Fort Fairfield" AND "LPOE" when:1685d
# ..                                      ...
# 341         "San Luis" AND "GSA" when:1685d
# 345         "San Luis" AND "GSA" when:1685d
# 346         "San Luis" AND "GSA" when:1685d
# 347         "San Luis" AND "GSA" when:1685d
# 349         "San Luis" AND "GSA" when:1685d
#
# [259 rows x 19 columns]

# %%
new_df_full_open_scrape["query"] = new_df_full_open_scrape["id"].map(lambda x: id2query_dict.get(x))


def datetime_of_struct_time(st: time.struct_time) -> datetime.datetime:
    "Convert a struct_time to datetime maintaining timezone information when present"
    tz = None
    if st.tm_gmtoff is not None:
        tz = datetime.timezone(datetime.timedelta(seconds=st.tm_gmtoff))
    # datetime doesn't like leap seconds so just truncate to 59 seconds
    if st.tm_sec in {60, 61}:
        return datetime.datetime(*st[:5], 59, tzinfo=tz)
    return datetime.datetime(*st[:6], tzinfo=tz)


new_df_full_open_scrape["published_datetime"] = new_df_full_open_scrape["published_parsed"].map(lambda x: datetime_of_struct_time(x))
new_df_full_open_scrape["published_year"] = new_df_full_open_scrape["published_datetime"].map(lambda x: x.year)
new_df_full_open_scrape["published_date"]= new_df_full_open_scrape["published_datetime"].map(lambda x: x.strftime("%Y-%m-%d"))

# extracting location for easier querying of excel sheet output
new_df_full_open_scrape["location"] = new_df_full_open_scrape["query"].map(lambda x: strip_punctuation(x[0].split(" AND")[0]))

# cleaning summary text
new_df_full_open_scrape["summary_text"] = new_df_full_open_scrape["summary"].map(lambda x: unicode_to_ascii(BeautifulSoup(x).get_text()))

# %%
# only selecting columns of interest
cols_of_interest = ['location', 'id',  'title', 'summary_text',  'link',  'published', 'published_date', 'published_year',
   'source.href', 'source.title', 'query',]

# showing two samples
new_df_full_open_scrape[cols_of_interest].sample(2)
# Out:
#      location                                                 id  \
# 346  San Luis  CBMivwFBVV95cUxNbVBYcVo1WjBYMVpzcFVZb1cwZXc5aT...
# 149  San Luis  CBMijAJBVV95cUxNbWYwd0JhclNzajFFX2VwZFNRVXN6cF...
#
#                                                  title  \
# 346  Hensel Phelps Awarded $174M GSA Contract for C...
# 149  Chaos ensues on US-Mexico border as Title 42 r...
#
#                                           summary_text  \
# 346  Hensel Phelps Awarded $174M GSA Contract for C...
# 149  Chaos ensues on US-Mexico border as Title 42 r...
#
#                                                   link  \
# 346  https://news.google.com/rss/articles/CBMivwFBV...
# 149  https://news.google.com/rss/articles/CBMijAJBV...
#
#                          published published_date  published_year  \
# 346  Mon, 29 Jul 2024 07:00:00 GMT     2024-07-29            2024
# 149  Fri, 12 May 2023 07:00:00 GMT     2023-05-12            2023
#
#                         source.href     source.title  \
# 346      https://www.govconwire.com      GovCon Wire
# 149  https://www.hindustantimes.com  Hindustan Times
#
#                                     query
# 346     ["San Luis" AND "GSA" when:1685d]
# 149  ["San Luis" AND "border" when:1685d]

# %%
# writing out output from rss feeder

new_df_full_open_scrape[cols_of_interest].to_excel("~/Downloads/google-news-articles-scrape-OGP-OCFO-LPOE-community-pulse-project.xlsx")

# %%
new_df_full_open_scrape[cols_of_interest]
# Out:
#            location                                                 id  \
# 0    Fort Fairfield  CBMiuAFBVV95cUxNZEZkRmc2VlpvNHlxVWF4cUZjNzd5S2...
# 1    Fort Fairfield  CBMilgFBVV95cUxOc2tpUGxKd3doSERTdVA1UDhWV1VpOG...
# 2    Fort Fairfield  CBMixAFBVV95cUxNNnBJeHBreVhhU082dnRGRml6b3NtS2...
# 3    Fort Fairfield  CBMieEFVX3lxTE5NYkdFZGdncjZVYnA0R1pPdUo4NUQ1VG...
# 4    Fort Fairfield  CBMikgFBVV95cUxQZEVFQ21rc1k4SF92OGRlbTJSRUNTbW...
# ..              ...                                                ...
# 341        San Luis  CBMi6gFBVV95cUxNUWJYWks3WUNHNDQzR0xGQTRrdlVuX0...
# 345        San Luis  CBMisgFBVV95cUxQWFZ5UE9hbUVhY0dKZmxfRUNDQmI3Nz...
# 346        San Luis  CBMivwFBVV95cUxNbVBYcVo1WjBYMVpzcFVZb1cwZXc5aT...
# 347        San Luis  CBMihgFBVV95cUxNRHZhbVpCREJmb0E2VG9uRFpjWkkwVk...
# 349        San Luis  CBMipgFBVV95cUxPcEhaZjJ4XzJ5Z0tOcVZMMElkNmctU3...
#
#                                                  title  \
# 0    Meetings will be held this week to discuss new...
# 1    Meeting on Fort Fairfield port of entry is Tue...
# 2    Fort Fairfield residents voice concerns about ...
# 3    Discussing the New Port of Entries in the Coun...
# 4    Residents’ Reply to Possible Closures of Port ...
# ..                                                 ...
# 341  Paso Robles GSA approves county as contracting...
# 345  WATCH: Kelly Gets Updates on Arizona Port of E...
# 346  Hensel Phelps Awarded $174M GSA Contract for C...
# 347  GSA to Spend $3.4 Billion to Update 26 Land Po...
# 349  A Water War Is Underway in Santa Barbara Count...
#
#                                           summary_text  \
# 0    Meetings will be held this week to discuss new...
# 1    Meeting on Fort Fairfield port of entry is Tue...
# 2    Fort Fairfield residents voice concerns about ...
# 3    Discussing the New Port of Entries in the Coun...
# 4    Residents’ Reply to Possible Closures of Port ...
# ..                                                 ...
# 341  Paso Robles GSA approves county as contracting...
# 345  WATCH: Kelly Gets Updates on Arizona Port of E...
# 346  Hensel Phelps Awarded $174M GSA Contract for C...
# 347  GSA to Spend $3.4 Billion to Update 26 Land Po...
# 349  A Water War Is Underway in Santa Barbara Count...
#
#                                                   link  \
# 0    https://news.google.com/rss/articles/CBMiuAFBV...
# 1    https://news.google.com/rss/articles/CBMilgFBV...
# 2    https://news.google.com/rss/articles/CBMixAFBV...
# 3    https://news.google.com/rss/articles/CBMieEFVX...
# 4    https://news.google.com/rss/articles/CBMikgFBV...
# ..                                                 ...
# 341  https://news.google.com/rss/articles/CBMi6gFBV...
# 345  https://news.google.com/rss/articles/CBMisgFBV...
# 346  https://news.google.com/rss/articles/CBMivwFBV...
# 347  https://news.google.com/rss/articles/CBMihgFBV...
# 349  https://news.google.com/rss/articles/CBMipgFBV...
#
#                          published published_date  published_year  \
# 0    Tue, 30 Jul 2024 07:00:00 GMT     2024-07-30            2024
# 1    Mon, 29 Jul 2024 14:14:37 GMT     2024-07-29            2024
# 2    Wed, 31 Jul 2024 20:58:28 GMT     2024-07-31            2024
# 3    Wed, 31 Jul 2024 07:00:00 GMT     2024-07-31            2024
# 4    Thu, 01 Aug 2024 07:00:00 GMT     2024-08-01            2024
# ..                             ...            ...             ...
# 341  Wed, 17 Jan 2024 08:00:00 GMT     2024-01-17            2024
# 345  Wed, 10 Jul 2024 07:00:00 GMT     2024-07-10            2024
# 346  Mon, 29 Jul 2024 07:00:00 GMT     2024-07-29            2024
# 347  Wed, 14 Dec 2022 08:00:00 GMT     2022-12-14            2022
# 349  Thu, 06 Jul 2023 07:00:00 GMT     2023-07-06            2023
#
#                          source.href               source.title  \
# 0             https://www.wagmtv.com                       WAGM
# 1               https://thecounty.me                 The County
# 2    https://www.bangordailynews.com          Bangor Daily News
# 3             https://www.wagmtv.com                       WAGM
# 4             https://www.wagmtv.com                       WAGM
# ..                               ...                        ...
# 341      https://pasoroblespress.com      The Paso Robles Press
# 345     https://www.kelly.senate.gov         Senator Mark Kelly
# 346       https://www.govconwire.com                GovCon Wire
# 347           https://www.ttnews.com           Transport Topics
# 349      https://www.independent.com  Santa Barbara Independent
#
#                                                  query
# 0    ["Fort Fairfield" AND "LPOE" when:1685d, "Fort...
# 1    ["Fort Fairfield" AND "LPOE" when:1685d, "Fort...
# 2    ["Fort Fairfield" AND "LPOE" when:1685d, "Fort...
# 3    ["Fort Fairfield" AND "LPOE" when:1685d, "Fort...
# 4    ["Fort Fairfield" AND "LPOE" when:1685d, "Fort...
# ..                                                 ...
# 341                  ["San Luis" AND "GSA" when:1685d]
# 345                  ["San Luis" AND "GSA" when:1685d]
# 346                  ["San Luis" AND "GSA" when:1685d]
# 347                  ["San Luis" AND "GSA" when:1685d]
# 349                  ["San Luis" AND "GSA" when:1685d]
#
# [259 rows x 11 columns]

# %%
import requests


resp = requests.get(example_url)

# %%
soup = BeautifulSoup(resp.text, "html.parser")
soup.get_text()
# Out:
# 'Google News'

# %%
with open("/Users/isabelmetzger/Downloads/example_html.html", "w") as fout:
    
    fout.write(str(BeautifulSoup(resp.text)))

# %%
q_d['"Fort Fairfield" AND "LPOE"']

l_dfs = []
for k,val in q_d.items():
    df_ = pd.concat([pd.DataFrame(val[0]["items"]), pd.DataFrame(val[1]["items"])]).reset_index(drop=True)
    df_["query"] = k
    l_dfs.append(df_)

# %%
service = build("customsearch", "v1", developerKey=my_api_key)


def google_search(service, query_keywords, api_key, cse_id, **kwargs):
    res = service.cse().list(q=query_keywords, cx=cse_id, **kwargs).execute()
    return res

def google_next_page(service, query_keywords, api_key, cse_id, res):
    next_res = service.cse().list(q=query_keywords, cx=cse_id, num=10, start=res['queries']['nextPage'][0]['startIndex'],).execute()
    return next_res

# %%
max_page = 4
q = '"Fort Fairfield" AND "LPOE"',
page = 0
all_res_list = []
while page < max_page:
    results = google_search(service, q, my_api_key, my_cse_id, num=10, gl="us", lr="lang_en")
    
    google_next_page(service, q, my_api_key, my_cse_id, res)
    
    page += 1
    if page == max_page:
        break
# Out:
# 35

# %%
first_res = service.cse().list(q=query, cx=my_cse_id, start=1, gl="us", lr="lang_en").execute()
second_res = service.cse().list(q=query, cx=my_cse_id, start=11, gl="us", lr="lang_en").execute()

# %%
for k, val in q_d.items():
    print(val[0]["items"])
    break
# Out:
# [{'kind': 'customsearch#result', 'title': 'Fort Fairfield Land Port of Entry, Maine | GSA', 'htmlTitle': '<b>Fort Fairfield</b> Land Port of Entry, Maine | GSA', 'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine', 'displayLink': 'www.gsa.gov', 'snippet': '7 days ago ... This project will deliver a new land port complex to supplement the existing LPOE in Fort Fairfield, Maine. Programming for the new LPOE\xa0...', 'htmlSnippet': '7 days ago <b>...</b> This project will deliver a new land port complex to supplement the existing <b>LPOE</b> in <b>Fort Fairfield</b>, Maine. Programming for the new <b>LPOE</b>&nbsp;...', 'formattedUrl': 'https://www.gsa.gov/about.../fort-fairfield-land-port-of-entry-maine', 'htmlFormattedUrl': 'https://www.gsa.gov/about.../<b>fort-fairfield</b>-land-port-of-entry-maine', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s', 'width': '275', 'height': '183'}], 'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg', 'og:type': 'website', 'og:image:alt': 'Photo of GSA headquarters', 'og:site_name': 'U.S. General Services Administration', 'handheldfriendly': 'true', 'viewport': 'width=device-width, initial-scale=1.0', 'og:title': 'Fort Fairfield Land Port of Entry, Maine', 'mobileoptimized': 'width', 'organization': 'R1', 'og:locale': 'en_US', 'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine', 'og:description': 'The Fort Fairfield Land Port of Entry modernization project will help Customs and Border Protection to more efficiently carry out its agency mission at the international border crossing between Fort Fairfield, Maine, and Carlingford, New Brunswick.'}], 'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}}, {'kind': 'customsearch#result', 'title': 'Land Ports of Entry Hours of Operation', 'htmlTitle': 'Land Ports of Entry Hours of Operation', 'link': 'https://www.dhs.gov/sites/default/files/2024-03/2024_0116_cbp_land_ports_of_entry_hours_of_operation.pdf', 'displayLink': 'www.dhs.gov', 'snippet': 'Jan 16, 2024 ... north of the LPOE that allows vehicles to circumvent inspection. ... Fort Fairfield, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24\xa0...', 'htmlSnippet': 'Jan 16, 2024 <b>...</b> north of the <b>LPOE</b> that allows vehicles to circumvent inspection. ... <b>Fort Fairfield</b>, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24&nbsp;...', 'formattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...', 'htmlFormattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz0cB8j2A5sEyWvJfIkx8pH0kr4nSs9hvhPKUpaPG-Bu74GGgi75UrTJ-L&s', 'width': '199', 'height': '253'}], 'metatags': [{'moddate': "D:20240301152537-05'00'", 'creationdate': "D:20240116100530-05'00'", 'creator': 'Adobe Acrobat Pro (64-bit) 23.6.20380', 'author': 'CBP', 'subject': 'CBP Land Ports of Entry Hours of Operation', 'producer': 'Adobe Acrobat Pro (64-bit) 23.6.20380', 'title': 'Land Ports of Entry Hours of Operation'}], 'cse_image': [{'src': 'x-raw-image:///2da3e8d4a7572571d0b7b49b0a5e6c9e5dc1011f66b819290ab9ce66d1636dfa'}]}, 'mime': 'application/pdf', 'fileFormat': 'PDF/Adobe Acrobat'}, {'kind': 'customsearch#result', 'title': 'R1 LPOE External Fact Sheet/Leave-Behind', 'htmlTitle': 'R1 <b>LPOE</b> External Fact Sheet/Leave-Behind', 'link': 'https://www.gsa.gov/system/files/Fort%20Fairfield%20update%20oct%202023.pdf', 'displayLink': 'www.gsa.gov', 'snippet': 'This project will deliver a new Land Port of Entry (LPOE) c ...

# %%
l_results = []

for q in query_list:
    l_results.append(google_search(service, q, my_api_key, my_cse_id,num=10, gl="us", lr="lang_en"))

# %%
df_search_info = pd.DataFrame(res["searchInformation"] for res in l_results)

# %%
df_search_info["query"] = query_list

# %%
res = google_search(service, q, my_api_key, my_cse_id)

# %%
res_l = google_next_page(service, '"Fort Fairfield" AND "LPOE"', my_api_key, my_cse_id, res, page=0, max_page=1, url_items=res["items"])

# %%
[val[0]["items"], val[1]["items"]]
# Out:
# [[{'kind': 'customsearch#result',
#    'title': 'General Services Administration Announces $100 Million ...',
#    'htmlTitle': '<b>General Services Administration</b> Announces $100 Million ...',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-9-pacific-rim/region-9-newsroom/pacific-rim-press-releases/general-services-administration-announces-100-mil-04032024',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'Apr 3, 2024 ... Federal investment transforms U.S.- Mexico Border into eco-friendly gateway SAN LUIS, Ariz. ㅡ The U.S. General Services Administration\xa0...',
#    'htmlSnippet': 'Apr 3, 2024 <b>...</b> Federal investment transforms U.S.- Mexico Border into eco-friendly gateway <b>SAN LUIS</b>, Ariz. ㅡ The U.S. <b>General Services Administration</b>&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/.../general-services-administration-announces-100-mil-...',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../<b>general-services-administration</b>-announces-100-mil-...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'General Services Administration Announces $100 Million Investment at Arizona’s San Luis I Land Port of Entry for Green Expansion as Part of President Biden’s Investing in America Agenda',
#       'mobileoptimized': 'width',
#       'organization': 'OSC',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-9-pacific-rim/region-9-newsroom/pacific-rim-press-releases/general-services-administration-announces-100-mil-04032024',
#       'og:description': 'Federal investment transforms U.S.- Mexico Border\xa0into eco-friendly gateway\xa0SAN LUIS, Ariz. ㅡ The U.S. General Services Administration (GSA) announced today $98.9 million in Inflation Reduction Act fu'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'General Services Administration Federal Supply Service',
#    'htmlTitle': '<b>General Services Administration</b> Federal Supply Service',
#    'link': 'https://www.gsaadvantage.gov/ref_text/GS35F0157Y/GS35F0157Y_online.htm',
#    'displayLink': 'www.gsaadvantage.gov',
#    'snippet': 'SAN LUIS AVIATION, INC. dba SLA. 3450 BROAD STREET, SUITE 106. SAN LUIS OBISPO ... 1194) General Services Administration (GSA), that all IT hardware/software/\xa0...',
#    'htmlSnippet': '<b>SAN LUIS</b> AVIATION, INC. dba SLA. 3450 BROAD STREET, SUITE 106. <b>SAN LUIS</b> OBISPO ... 1194) <b>General Services Administration</b> (GSA), that all IT hardware/software/&nbsp;...',
#    'formattedUrl': 'https://www.gsaadvantage.gov/ref_text/.../GS35F0157Y_online.htm',
#    'htmlFormattedUrl': 'https://www.gsaadvantage.gov/ref_text/.../GS35F0157Y_online.htm',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPd-64sUyQus_O56jRjQA7CDzzn-ODA23Yms5lNAqrkU_cCxUpo4uc96E&s',
#       'width': '219',
#       'height': '114'}],
#     'metatags': [{'moddate': "D:20220313121108-07'00'",
#       'creationdate': "D:20220313121104-07'00'",
#       'creator': 'Acrobat PDFMaker 21 for Word',
#       'sourcemodified': 'D:20220313191052',
#       'author': 'fadi eidi',
#       'producer': 'Adobe PDF Library 21.11.71',
#       'company': 'GSA',
#       'title': '______________________'}],
#     'cse_image': [{'src': 'x-raw-image:///b24177b65b0ec81a934000c8bef63f14e26ba77482366893ac61ee17fc7f0f83'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'GSA Administrator Visits Arizona to Announce First Inflation ...',
#    'htmlTitle': 'GSA Administrator Visits Arizona to Announce First Inflation ...',
#    'link': 'https://www.gsa.gov/about-us/newsroom/news-releases/gsa-administrator-visits-arizona-to-announce-first-inflation-reduction-act-projects-at-federal-facilities-12192022',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'Dec 19, 2022 ... SAN LUIS, AZ – The U.S. General Services Administration today announced more than $300 million in construction and renovation projects\xa0...',
#    'htmlSnippet': 'Dec 19, 2022 <b>...</b> <b>SAN LUIS</b>, AZ – The U.S. <b>General Services Administration</b> today announced more than $300 million in construction and renovation projects&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/.../gsa-administrator-visits-arizona-to-announce-first-in...',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../gsa-administrator-visits-arizona-to-announce-first-in...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'GSA Administrator Visits Arizona to Announce First Inflation Reduction Act Projects at Federal Facilities',
#       'mobileoptimized': 'width',
#       'organization': 'OSC',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/newsroom/news-releases/gsa-administrator-visits-arizona-to-announce-first-inflation-reduction-act-projects-at-federal-facilities-12192022',
#       'og:description': 'Capital projects and retrofits aim to spur emerging technologies and boost demand for low-carbon construction materialsSAN LUIS, AZ – The U.S. General Services Administration today announced more...'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'News Flash • Biden-Harris Administration breaks ground on $3',
#    'htmlTitle': 'News Flash • Biden-Harris Administration breaks ground on $3',
#    'link': 'https://www.sanluisaz.gov/CivicAlerts.aspx?AID=677',
#    'displayLink': 'www.sanluisaz.gov',
#    'snippet': 'Jun 29, 2023 ... SAN LUIS, Ariz. - Today, the U.S. General Services Administration (GSA) and the U.S. Department of Homeland Security - Customs and Border\xa0...',
#    'htmlSnippet': 'Jun 29, 2023 <b>...</b> <b>SAN LUIS</b>, Ariz. - Today, the U.S. <b>General Services Administration</b> (GSA) and the U.S. Department of Homeland Security - Customs and Border&nbsp;...',
#    'formattedUrl': 'https://www.sanluisaz.gov/CivicAlerts.aspx?AID=677',
#    'htmlFormattedUrl': 'https://www.<b>sanluis</b>az.gov/CivicAlerts.aspx?AID=677',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQb-9q0R5WdKzuWUELv0g4y6DTrYqSX8jWl2vOm-VpIL6QEK619e7mJlQQw&s',
#       'width': '294',
#       'height': '171'}],
#     'metatags': [{'msapplication-tilecolor': '#2b5797',
#       'og:image': 'https://www.sanluisaz.gov/ImageRepository/Document?documentID=11331',
#       'theme-color': '#ffffff',
#       'twitter:title': 'Biden-Harris Administration breaks ground on $308 million port modernization and expansion project',
#       'twitter:card': 'summary',
#       'og:site_name': 'San Luis, AZ',
#       'twitter:url': 'https://www.sanluisaz.gov/CivicAlerts.aspx?AID=677',
#       'og:title': 'Biden-Harris Administration breaks ground on $308 million port modernization and expansion project',
#       'og:description': '&nbsp;',
#       'twitter:image': 'https://www.sanluisaz.gov/ImageRepository/Document?documentID=11331',
#       'twitter:site': 'San Luis, AZ',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': '&nbsp;',
#       'og:url': 'https://www.sanluisaz.gov/CivicAlerts.aspx?AID=677'}],
#     'cse_image': [{'src': 'https://www.sanluisaz.gov/ImageRepository/Document?documentID=11331'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Monica Cater - Project Manager - General Services Administration ...',
#    'htmlTitle': 'Monica Cater - Project Manager - <b>General Services Administration</b> ...',
#    'link': 'https://www.linkedin.com/in/monica-cater-b7955210',
#    'displayLink': 'www.linkedin.com',
#    'snippet': 'Project Manager at General Services Administration · Experience: General Services Administration ... San Luis Obispo · Location: San Francisco · 285 connections',
#    'htmlSnippet': 'Project Manager at <b>General Services Administration</b> · Experience: <b>General Services Administration</b> ... <b>San Luis</b> Obispo · Location: San Francisco · 285 connections',
#    'formattedUrl': 'https://www.linkedin.com/in/monica-cater-b7955210',
#    'htmlFormattedUrl': 'https://www.linkedin.com/in/monica-cater-b7955210',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1AiYMp4Ins6zY82qgSholwnqfaOurrx2-EqmytxEmEbDIfzkkeRhzenvT&s',
#       'width': '200',
#       'height': '200'}],
#     'metatags': [{'og:image': 'https://media.licdn.com/dms/image/C5603AQGgmBSR68M6Jg/profile-displayphoto-shrink_200_200/0/1656919543504?e=2147483647&v=beta&t=nFfrDkjAU_aop6M9iQy9YOpxO-ouLqvr03sPYjXGDSo',
#       'twitter:card': 'summary',
#       'linkedin:pagetag': 'openToProvider',
#       'platform-worker': 'https://static.licdn.com/aero-v1/sc/h/7nirg34a8ey4y2l4rw7xgwxx4',
#       'al:android:package': 'com.linkedin.android',
#       'bingbot': 'nocache',
#       'locale': 'en_US',
#       'al:ios:url': 'https://www.linkedin.com/in/monica-cater-b7955210',
#       'og:description': 'Project Manager at General Services Administration · Experience: General Services Administration · Education: California Polytechnic State University-San Luis Obispo · Location: San Francisco · 285 connections on LinkedIn. View Monica Cater’s profile on LinkedIn, a professional community of 1 billion members.',
#       'al:ios:app_store_id': '288429040',
#       'platform': 'https://static.licdn.com/aero-v1/sc/h/2km291q2pegh0x2oidlktzeqm',
#       'twitter:image': 'https://media.licdn.com/dms/image/C5603AQGgmBSR68M6Jg/profile-displayphoto-shrink_200_200/0/1656919543504?e=2147483647&v=beta&t=nFfrDkjAU_aop6M9iQy9YOpxO-ouLqvr03sPYjXGDSo',
#       'profile:last_name': 'Cater',
#       'twitter:site': '@Linkedin',
#       'litmsprofilename': 'public-profile-frontend',
#       'profile:first_name': 'Monica',
#       'og:type': 'profile',
#       'twitter:title': 'Monica Cater - Project Manager - General Services Administration | LinkedIn',
#       'al:ios:app_name': 'LinkedIn',
#       'og:title': 'Monica Cater - Project Manager - General Services Administration | LinkedIn',
#       'pagekey': 'public_profile_v3_mobile',
#       'al:android:url': 'https://www.linkedin.com/in/monica-cater-b7955210',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'Project Manager at General Services Administration · Experience: General Services Administration · Education: California Polytechnic State University-San Luis Obispo · Location: San Francisco · 285 connections on LinkedIn. View Monica Cater’s profile on LinkedIn, a professional community of 1 billion members.',
#       'ubba': 'https://static.licdn.com/aero-v1/sc/h/d9ms43pfjxq6gxw43cx6a1ow2',
#       'og:url': 'https://www.linkedin.com/in/monica-cater-b7955210',
#       'al:android:app_name': 'LinkedIn'}],
#     'cse_image': [{'src': 'https://media.licdn.com/dms/image/C5603AQGgmBSR68M6Jg/profile-displayphoto-shrink_200_200/0/1656919543504?e=2147483647&v=beta&t=nFfrDkjAU_aop6M9iQy9YOpxO-ouLqvr03sPYjXGDSo'}],
#     'Person': [{}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Arizona Land Ports of Entry Modernization Projects - Center for ...',
#    'htmlTitle': 'Arizona Land Ports of Entry Modernization Projects - Center for ...',
#    'link': 'https://www.americanprogress.org/article/arizona-land-ports-of-entry-modernization-projects/',
#    'displayLink': 'www.americanprogress.org',
#    'snippet': 'Jun 27, 2023 ... ... San Luis.” – U.S. General Services Administration, last accessed April 2023; The existing Castro LPOE has placed a commercial inspection\xa0...',
#    'htmlSnippet': 'Jun 27, 2023 <b>...</b> ... <b>San Luis</b>.” – U.S. <b>General Services Administration</b>, last accessed April 2023; The existing Castro LPOE has placed a commercial inspection&nbsp;...',
#    'formattedUrl': 'https://www.americanprogress.org/.../arizona-land-ports-of-entry-moderniz...',
#    'htmlFormattedUrl': 'https://www.americanprogress.org/.../arizona-land-ports-of-entry-moderniz...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQLB2TstlEJNd8ZyQfApc5U8XYOGPTy9xkCT8jJjlHndBoBrWLiHKqkU90&s',
#       'width': '275',
#       'height': '183'}],
#     'document': [{'website': 'Center for American Progress',
#       'issue': 'Building an Economy for All',
#       'topics': 'Biden Administration;Economy;Growing the Middle Class;Infrastructure;State and Local Policy;Transportation',
#       'description': 'A $500 million investment from the Infrastructure Investment and Jobs Act will allow two land ports of entry on the Arizona-Mexico border to be modernized and a new one to be constructed, facilitating safe and efficient flow of people and goods in the region.',
#       'type': 'Article',
#       'title': 'Arizona Land Ports of Entry Modernization Projects',
#       'post_id': '102094',
#       'post_date': '06/27/2023',
#       'series': 'Tracking Biden Administration Investment Projects',
#       'last_update': '07/19/2023',
#       'state': 'Arizona',
#       'department': 'Advocacy and Outreach',
#       'slug': 'arizona-land-ports-of-entry-modernization-projects'}],
#     'metatags': [{'msapplication-tilecolor': '#ffffff',
#       'og:image': 'https://www.americanprogress.org/wp-content/uploads/sites/2/2023/06/GettyImages-162783626cropped.jpg',
#       'msapplication-config': 'https://www.americanprogress.org/wp-content/themes/cap2021/assets/favicons/browserconfig.xml',
#       'og:type': 'article',
#       'og:image:width': '1680',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#ffffff',
#       'og:site_name': 'Center for American Progress',
#       'og:title': 'Arizona Land Ports of Entry Modernization Projects',
#       'og:image:height': '1120',
#       'og:image:type': 'image/jpeg',
#       'og:description': 'A $500 million investment from the Infrastructure Investment and Jobs Act will allow two land ports of entry on the Arizona-Mexico border to be modernized and a new one to be constructed, facilitating safe and efficient flow of people and goods in the region.',
#       'parsely-tags': 'Issue: Building an Economy for All,Topic: Biden Administration,Topic: Economy,Topic: Growing the Middle Class,Topic: Infrastructure,Topic: State and Local Policy,Topic: Transportation,Post Type: article,State/Territory: Arizona,Department: Advocacy and Outreach,Series: Tracking Biden Administration Investment Projects,Article Type: Article',
#       'article:modified_time': '2023-07-19T17:59:25+00:00',
#       'viewport': 'width=device-width, initial-scale=1.0, viewport-fit=cover',
#       'og:locale': 'en_US',
#       'parsely-section': 'article',
#       'og:url': 'https://www.americanprogress.org/article/arizona-land-ports-of-entry-modernization-projects/'}],
#     'cse_image': [{'src': 'https://www.americanprogress.org/wp-content/uploads/sites/2/2023/06/GettyImages-162783626cropped.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Liondandies in Yuma, AZ',
#    'htmlTitle': 'Liondandies in Yuma, AZ',
#    'link': 'https://publicartarchive.org/art/Liondandies/03e3b6d4',
#    'displayLink': 'publicartarchive.org',
#    'snippet': 'Explore works by John Bisbee and the US General Services Administration collection on Public Art Archive ... San Luis, AZ. About · Collection Management\xa0...',
#    'htmlSnippet': 'Explore works by John Bisbee and the US <b>General Services Administration</b> collection on Public Art Archive ... <b>San Luis</b>, AZ. About &middot; Collection Management&nbsp;...',
#    'formattedUrl': 'https://publicartarchive.org/art/Liondandies/03e3b6d4',
#    'htmlFormattedUrl': 'https://publicartarchive.org/art/Liondandies/03e3b6d4',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ6STN0Kv8879x4njjT-rytxB4QgZHFGZ5mBz_phRxGhlIk3lfV8IbMIFI&s',
#       'width': '270',
#       'height': '187'}],
#     'metatags': [{'og:image': 'https://d32q37k5f6yh2c.cloudfront.net/media/79/796a383161aa9f98cc6f7239d69b0819',
#       'twitter:title': 'Liondandies in Yuma, AZ',
#       'og:type': 'website',
#       'og:site_name': 'Public Art Archive',
#       'twitter:url': 'https://publicartarchive.org/art/Liondandies/03e3b6d4',
#       'og:title': 'Liondandies in Yuma, AZ',
#       'og:description': 'Explore works by John Bisbee and the US General Services Administration collection on Public Art Archive.',
#       'twitter:image': 'https://d32q37k5f6yh2c.cloudfront.net/media/79/796a383161aa9f98cc6f7239d69b0819',
#       'next-head-count': '16',
#       'twitter:site_name': 'Public Art Archive',
#       'viewport': 'width=device-width',
#       'twitter:description': 'Explore works by John Bisbee and the US General Services Administration collection on Public Art Archive.',
#       'og:url': 'https://publicartarchive.org/art/Liondandies/03e3b6d4',
#       'twitter:type': 'website'}],
#     'cse_image': [{'src': 'https://d32q37k5f6yh2c.cloudfront.net/media/7e/7e670b8e861aa229ba1964223322fb68_thumb'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'NEWS RELEASE: San Luis I Port of Entry Modernization Project',
#    'htmlTitle': 'NEWS RELEASE: <b>San Luis</b> I Port of Entry Modernization Project',
#    'link': 'https://www.somertonaz.gov/news_detail_T8_R258.php',
#    'displayLink': 'www.somertonaz.gov',
#    'snippet': 'Apr 19, 2024 ... San Luis, Arizona ... The project is being facilitated by the General Services Administration and has an impressive budget of $307 million.',
#    'htmlSnippet': 'Apr 19, 2024 <b>...</b> <b>San Luis</b>, Arizona ... The project is being facilitated by the <b>General Services Administration</b> and has an impressive budget of $307 million.',
#    'formattedUrl': 'https://www.somertonaz.gov/news_detail_T8_R258.php',
#    'htmlFormattedUrl': 'https://www.somertonaz.gov/news_detail_T8_R258.php',
#    'pagemap': {'metatags': [{'viewport': 'width=device-width'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'About Us - The San Luis Resort',
#    'htmlTitle': 'About Us - The <b>San Luis</b> Resort',
#    'link': 'https://www.sanluisresort.com/aboutus.asp',
#    'displayLink': 'www.sanluisresort.com',
#    'snippet': '... San Luis. The ... In 1953, Fort Crockett was declared surplus, and three years later was released to the General Services Administration for disposal.',
#    'htmlSnippet': '... <b>San Luis</b>. The ... In 1953, Fort Crockett was declared surplus, and three years later was released to the <b>General Services Administration</b> for disposal.',
#    'formattedUrl': 'https://www.sanluisresort.com/aboutus.asp',
#    'htmlFormattedUrl': 'https://www.<b>sanluis</b>resort.com/aboutus.asp',
#    'pagemap': {'metatags': [{'viewport': 'width=device-width, initial-scale=1',
#       'author': 'Landrys inc.',
#       'facebook-domain-verification': 'qu5d7qt0rhremf57prgyw0dn9ohtti'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'U.S. General Services Administration Pacific Rim Region',
#    'htmlTitle': 'U.S. <b>General Services Administration</b> Pacific Rim Region',
#    'link': 'https://www.facebook.com/gsapacificrimregion/',
#    'displayLink': 'www.facebook.com',
#    'snippet': 'U.S. General Services Administration Pacific Rim Region. 2527 likes · 12 ... San Luis I del 22 de julio al 9 de agosto de 2024, de 9 p.m. a 6 a.m. Al\xa0...',
#    'htmlSnippet': 'U.S. <b>General Services Administration</b> Pacific Rim Region. 2527 likes · 12 ... <b>San Luis</b> I del 22 de julio al 9 de agosto de 2024, de 9 p.m. a 6 a.m. Al&nbsp;...',
#    'formattedUrl': 'https://www.facebook.com/gsapacificrimregion/',
#    'htmlFormattedUrl': 'https://www.facebook.com/gsapacificrimregion/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRHhItlIMEeMFTT5VSJmuvd-1Ku2XR5ST6ddghXUFdIDMkMub0Yf3PHI5eI&s',
#       'width': '224',
#       'height': '224'}],
#     'metatags': [{'apple-itunes-app': 'app-id=284882215, app-argument=fb://profile/100064486758250',
#       'og:image': 'https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100064486758250',
#       'og:type': 'video.other',
#       'og:image:alt': 'U.S. General Services Administration Pacific Rim Region',
#       'twitter:card': 'summary',
#       'twitter:title': 'U.S. General Services Administration Pacific Rim Region',
#       'theme-color': '#FFFFFF',
#       'al:ios:app_name': 'Facebook',
#       'og:title': 'U.S. General Services Administration Pacific Rim Region',
#       'al:android:package': 'com.facebook.katana',
#       'google': 'notranslate',
#       'al:ios:url': 'fb://profile/100064486758250',
#       'og:description': 'U.S. General Services Administration Pacific Rim Region. 2,527 likes · 12 talking about this. Welcome to the Pacific Rim Region',
#       'al:ios:app_store_id': '284882215',
#       'twitter:image': 'https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100064486758250',
#       'al:android:url': 'fb://profile/100064486758250',
#       'referrer': 'origin-when-crossorigin',
#       'twitter:image:alt': 'U.S. General Services Administration Pacific Rim Region',
#       'twitter:site': '@facebookapp',
#       'viewport': 'width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no',
#       'twitter:description': 'U.S. General Services Administration Pacific Rim Region. 2,527 likes · 12 talking about this. Welcome to the Pacific Rim Region',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.facebook.com/gsapacificrimregion/',
#       'al:android:app_name': 'Facebook'}],
#     'cse_image': [{'src': 'https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100064486758250'}]}}],
#  [{'kind': 'customsearch#result',
#    'title': 'Maquette for Bien Venida y Vaya Con Dios | Smithsonian American ...',
#    'htmlTitle': 'Maquette for Bien Venida y Vaya Con Dios | Smithsonian American ...',
#    'link': 'https://americanart.si.edu/artwork/maquette-bien-venida-y-vaya-con-dios-31950',
#    'displayLink': 'americanart.si.edu',
#    'snippet': '... which translates as "Welcome and Go With God," was commissioned by the General Services Administration for the border station in San Luis, Arizona.',
#    'htmlSnippet': '... which translates as &quot;Welcome and Go With God,&quot; was commissioned by the <b>General Services Administration</b> for the border station in <b>San Luis</b>, Arizona.',
#    'formattedUrl': 'https://americanart.si.edu/.../maquette-bien-venida-y-vaya-con-dios-31950',
#    'htmlFormattedUrl': 'https://americanart.si.edu/.../maquette-bien-venida-y-vaya-con-dios-31950',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJq0bZ2CXefBFsgZhk2kEUOprCgxhQD0vmVK8Y-GBIsV-xFXsxdBHlj4Y&s',
#       'width': '208',
#       'height': '243'}],
#     'metatags': [{'og:image': 'https://ids.si.edu/ids/deliveryService?id=SAAM-1990.69A-B_1&max=960',
#       'og:type': 'article',
#       'article:section': 'Art',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Maquette for Bien Venida y Vaya Con Dios',
#       'og:site_name': 'Smithsonian American Art Museum',
#       'twitter:site:id': '@americanart',
#       'geo.region': 'US',
#       'handheldfriendly': 'true',
#       'msvalidate.01': 'C524AA89AB0E59F5DC8A8C73F67C655F',
#       'og:title': 'Maquette for Bien Venida y Vaya Con Dios',
#       'og:description': 'Bien Venida y Vaya Con Dios, which translates as "Welcome and Go With God," was commissioned by the General Services Administration for the border station in San Luis, Arizona.',
#       'twitter:image': 'https://ids.si.edu/ids/deliveryService?id=SAAM-1990.69A-B_1&max=960',
#       'referrer': 'no-referrer-when-downgrade',
#       'twitter:site': '@americanart',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'Bien Venida y Vaya Con Dios, which translates as "Welcome and Go With God," was commissioned by the General Services Administration for the border station in San Luis, Arizona.',
#       'rights': 'Unrestricted (Transfer of Copyright)',
#       'mobileoptimized': '480',
#       'fb:admins': '29428791399',
#       'og:url': 'https://americanart.si.edu/artwork/maquette-bien-venida-y-vaya-con-dios-31950'}],
#     'cse_image': [{'src': 'https://ids.si.edu/ids/deliveryService?id=SAAM-1990.69A-B_1&max=960'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'ABC 5 News - The U.S. General Services Administration... | Facebook',
#    'htmlTitle': 'ABC 5 News - The U.S. <b>General Services Administration</b>... | Facebook',
#    'link': 'https://www.facebook.com/ABC5Yuma/posts/the-us-general-services-administration-gsa-says-the-san-luis-i-land-port-of-entr/5875344719193152/',
#    'displayLink': 'www.facebook.com',
#    'snippet': 'Dec 19, 2022 ... The U.S. General Services Administration (GSA) says the San Luis I Land Port of Entry is one of the projects to receive funding for\xa0...',
#    'htmlSnippet': 'Dec 19, 2022 <b>...</b> The U.S. <b>General Services Administration</b> (GSA) says the <b>San Luis</b> I Land Port of Entry is one of the projects to receive funding for&nbsp;...',
#    'formattedUrl': 'https://www.facebook.com/...general-services-administration...san-luis.../58...',
#    'htmlFormattedUrl': 'https://www.facebook.com/...<b>general-services-administration</b>...<b>san-luis</b>.../58...',
#    'pagemap': {'metatags': [{'og:image': 'https://external-iad3-2.xx.fbcdn.net/emg1/v/t13/363916731039593209?url=https%3a%2f%2fkyma.b-cdn.net%2f2022%2f12%2fScreen-Shot-2022-12-19-at-6.33.09-PM.png&fb_obo=1&utld=b-cdn.net&stp=c0.5000x0.5000f_dst-jpg_flffffff_p600x600_q75&ccb=13-1&oh=06_Q399Q6GO7zHB17rI1UoxQQSykOnO9KtWgUWbLcR29FcjCfw&oe=66A2481F&_nc_sid=867500',
#       'og:type': 'video.other',
#       'og:image:alt': 'ABC 5 News',
#       'twitter:card': 'summary',
#       'twitter:title': 'ABC 5 News',
#       'theme-color': '#FFFFFF',
#       'og:title': 'ABC 5 News',
#       'google': 'notranslate',
#       'og:description': 'The U.S. General Services Administration (GSA) says the San Luis I Land Port of Entry is one of the projects to receive funding for expansion and renewal.',
#       'twitter:image': 'https://external-iad3-2.xx.fbcdn.net/emg1/v/t13/363916731039593209?url=https%3A%2F%2Fkyma.b-cdn.net%2F2022%2F12%2FScreen-Shot-2022-12-19-at-6.33.09-PM.png&fb_obo=1&utld=b-cdn.net&stp=c0.5000x0.5000f_dst-jpg_flffffff_p600x600_q75&ccb=13-1&oh=06_Q399Q6GO7zHB17rI1UoxQQSykOnO9KtWgUWbLcR29FcjCfw&oe=66A2481F&_nc_sid=867500',
#       'referrer': 'origin-when-crossorigin',
#       'twitter:image:alt': 'ABC 5 News',
#       'twitter:site': '@facebookapp',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'The U.S. General Services Administration (GSA) says the San Luis I Land Port of Entry is one of the projects to receive funding for expansion and renewal.',
#       'og:locale': 'en_US',
#       'fb-version': '418.0.0.0.74:2571',
#       'og:url': 'https://www.facebook.com/ABC5Yuma/posts/the-us-general-services-administration-gsa-says-the-san-luis-i-land-port-of-entr/5875344719193152/'}],
#     'cse_image': [{'src': 'https://external-iad3-2.xx.fbcdn.net/emg1/v/t13/363916731039593209?url=https%3a%2f%2fkyma.b-cdn.net%2f2022%2f12%2fScreen-Shot-2022-12-19-at-6.33.09-PM.png&fb_obo=1&utld=b-cdn.net&stp=c0.5000x0.5000f_dst-jpg_flffffff_p600x600_q75&ccb=13-1&oh=06_Q399Q6GO7zHB17rI1UoxQQSykOnO9KtWgUWbLcR29FcjCfw&oe=66A2481F&_nc_sid=867500'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Filter Events',
#    'htmlTitle': 'Filter Events',
#    'link': 'https://www.dgs.ca.gov/en/PD/Events',
#    'displayLink': 'www.dgs.ca.gov',
#    'snippet': '... San Luis Obispo, CA 93405. Create connections across the CSU system · 30 Jul ... Doing Business with the U.S. General Services Administration (GSA).',
#    'htmlSnippet': '... <b>San Luis</b> Obispo, CA 93405. Create connections across the CSU system &middot; 30 Jul ... Doing Business with the U.S. <b>General Services Administration</b> (GSA).',
#    'formattedUrl': 'https://www.dgs.ca.gov/en/PD/Events',
#    'htmlFormattedUrl': 'https://www.dgs.ca.gov/en/PD/Events',
#    'pagemap': {'hcalendar': [{'summary': 'Biz Expo 2024',
#       'description': 'Outreach',
#       'dtstart_time': '08:31',
#       'dtstart': '2024-07-24'},
#      {'summary': 'North Region 2024 Resource Roundtable',
#       'description': 'Workshops',
#       'dtstart_time': '08:39',
#       'dtstart': '2024-07-24'},
#      {'summary': 'Solving the Marketing Mystery: Strategies for How to Market to the State – Session 2',
#       'description': 'Outreach',
#       'dtstart_time': '12:04',
#       'dtstart': '2024-07-25'},
#      {'summary': '4th Annual Small Business Success Summit',
#       'description': 'Outreach',
#       'dtstart_time': '08:53',
#       'dtstart': '2024-07-27'},
#      {'summary': 'California State University Small Business Expo',
#       'description': 'Outreach',
#       'dtstart_time': '10:11',
#       'dtstart': '2024-07-30'},
#      {'summary': 'Prepare for the Fair',
#       'description': 'Outreach',
#       'dtstart_time': '11:28',
#       'dtstart': '2024-07-30'},
#      {'summary': 'The ABCs of Environmentally Preferable Purchasing for SB/DVBEs',
#       'description': 'Training',
#       'dtstart_time': '08:40',
#       'dtstart': '2024-08-08'},
#      {'summary': 'Doing Business with the U.S. General Services Administration (GSA)',
#       'description': 'Outreach',
#       'dtstart_time': '10:05',
#       'dtstart': '2024-08-13'},
#      {'summary': '20th Annual Procurement Resource Fair-8-14-24',
#       'description': 'Outreach',
#       'dtstart_time': '10:18',
#       'dtstart': '2024-08-14'},
#      {'summary': 'Contracting with California State Government',
#       'description': 'Outreach',
#       'dtstart_time': '10:19',
#       'dtstart': '2024-08-15'},
#      {'summary': 'California Hispanic Chamber of Commerce 45th Annual Statewide Convention',
#       'description': 'Outreach',
#       'dtstart_time': '11:40',
#       'dtstart': '2024-08-21'},
#      {'summary': 'Small Business Advisory Council Meeting',
#       'description': 'Outreach',
#       'dtstart_time': '06:47',
#       'dtstart': '2024-09-04'},
#      {'summary': 'Solving the Marketing Mystery: the 5Ws - Session 1',
#       'description': 'Training',
#       'dtstart_time': '08:11',
#       'dtstart': '2024-12-05'}],
#     'metatags': [{'handheldfriendly': 'True',
#       'viewport': 'width=device-width, initial-scale=1.0, minimum-scale=1.0',
#       'mobileoptimized': '320'}],
#     'event': [{'summary': 'Biz Expo 2024',
#       'location': 'Sheraton Fairplex and Conference Center, 601 W McKinley Ave, Pomona, CA 91768',
#       'dtstart': '2024-07-24'},
#      {'name': 'Biz Expo 2024',
#       'about': 'Learn more about energy, housing, financing, technology, AI, and more.',
#       'description': 'Outreach',
#       'location': 'Sheraton Fairplex and Conference Center, 601 W McKinley Ave, Pomona, CA 91768',
#       'startdate': '2024-07-24T08:31'},
#      {'name': 'North Region 2024 Resource Roundtable',
#       'about': 'Network with resource partner agencies.',
#       'description': 'Workshops',
#       'location': 'Online by webinar',
#       'startdate': '2024-07-24T08:39'},
#      {'name': 'Solving the Marketing Mystery: Strategies for How to Market to the State – Session 2',
#       'about': 'Learn how to build relationships with buyers',
#       'description': 'Outreach',
#       'location': 'Online by webinar',
#       'startdate': '2024-07-25T12:04'},
#      {'name': '4th Annual Small Business Success Summit',
#       'about': 'Building a better business model.',
#       'description': 'Outreach',
#       'location': '2251 Florin Road Sacramento, CA 95822',
#       'startdate': '2024-07-27T08:53'},
#      {'name': 'California State University Small Business Expo',
#       'about': 'Create connections across the CSU system',
#       'description': 'Outreach',
#       'location': 'Julian A. McPhee University Union, S. Poly View Drive, San Luis Obispo, CA 93405',
#       'startdate': '2024-07-30T10:11'},
#      {'name': 'Prepare for the Fair',
#       'about': 'Gain the knowledge necessary to do business with Caltrans and government buyers',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-07-30T11:28'},
#      {'name': 'The ABCs of Environmentally Preferable Purchasing for SB/DVBEs',
#       'about': 'Did you know as a business selling to the state of California, there are Environmentally Preferable Purchasing requirements in some solicitations?',
#       'description': 'Training',
#       'location': 'Virtual',
#       'startdate': '2024-08-08T08:40'},
#      {'name': 'Doing Business with the U.S. General Services Administration (GSA)',
#       'about': 'Get your piece of the $84 billion the GSA purchases.',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-08-13T10:05'},
#      {'name': '20th Annual Procurement Resource Fair-8-14-24',
#       'about': 'Get your business ready for government contracting.',
#       'description': 'Outreach',
#       'location': 'Caltrans District 11 Office, 4050 Taylor Street, San Diego, CA 92110',
#       'startdate': '2024-08-14T10:18'},
#      {'name': 'Contracting with California State Government',
#       'about': 'Discover the state’s procurement methods to grow your business',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-08-15T10:19'},
#      {'name': 'California Hispanic Chamber of Commerce 45th Annual Statewide Convention',
#       'about': 'Be inspired and champion your growth, innovation, and empowerment.',
#       'description': 'Outreach',
#       'location': 'Bakersfield Marriott at the Convention Center, 801 Truxtun Ave., Bakersfield, CA 93301',
#       'startdate': '2024-08-21T11:40'},
#      {'name': 'Small Business Advisory Council Meeting',
#       'about': 'A forum for representatives of the California small business community to provide input on policies and practices.',
#       'description': 'Outreach',
#       'location': 'DGS Ziggurat Building- 707 Third Street, West Sacramento, CA 95605 from 1 to 4 p.m.',
#       'startdate': '2024-09-04T06:47'},
#      {'name': 'Solving the Marketing Mystery: the 5Ws - Session 1',
#       'about': 'Solve the Marketing Mystery of state procurement by utilizing the 5Ws: Why, What, Where, Who and When.',
#       'description': 'Training',
#       'location': 'Virtual',
#       'startdate': '2024-12-05T08:11'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Federal Buildings Fund, General Services Administration | Spending ...',
#    'htmlTitle': 'Federal Buildings Fund, <b>General Services Administration</b> | Spending ...',
#    'link': 'https://www.usaspending.gov/federal_account/047-4542',
#    'displayLink': 'www.usaspending.gov',
#    'snippet': 'View the spending activity of the federal account for Federal Buildings Fund, General Services Administration ... SAN LUIS I LAND POR...',
#    'htmlSnippet': 'View the spending activity of the federal account for Federal Buildings Fund, <b>General Services Administration</b> ... <b>SAN LUIS</b> I LAND POR...',
#    'formattedUrl': 'https://www.usaspending.gov/federal_account/047-4542',
#    'htmlFormattedUrl': 'https://www.usaspending.gov/federal_account/047-4542',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRb6HktqYhfkm9BpGIINNclAbJnK-K8o_r0hfHdvdTbALKO8c1ESglQJrPe&s',
#       'width': '310',
#       'height': '163'}],
#     'metatags': [{'og:image': 'https://usaspending.gov/img/social-share-preview_account.png',
#       'og:type': 'website',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Federal Buildings Fund, General Services Administration | Spending Profile | USAspending',
#       'viewport': 'width=device-width,initial-scale=1',
#       'twitter:description': 'View the spending activity of the federal account for Federal Buildings Fund, General Services Administration.',
#       'og:title': 'Federal Buildings Fund, General Services Administration | Spending Profile | USAspending',
#       'og:url': 'https://usaspending.gov/federal_account/047-4542',
#       'twitter:image': 'https://usaspending.gov/img/social-share-preview_account.png'}],
#     'cse_image': [{'src': 'https://usaspending.gov/img/social-share-preview_account.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'News - Greater Yuma Port Authority',
#    'htmlTitle': 'News - Greater Yuma Port Authority',
#    'link': 'https://gypa.org/articles.html',
#    'displayLink': 'gypa.org',
#    'snippet': '... San Luis I Land Port of Entry, San Luis, Arizona · Read More · Announcement of ... -- Today, the U.S. General Services Administration (GSA), the U.S.\xa0...',
#    'htmlSnippet': '... <b>San Luis</b> I Land Port of Entry, <b>San Luis</b>, Arizona &middot; Read More &middot; Announcement of ... -- Today, the U.S. <b>General Services Administration</b> (GSA), the U.S.&nbsp;...',
#    'formattedUrl': 'https://gypa.org/articles.html',
#    'htmlFormattedUrl': 'https://gypa.org/articles.html',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT_n9mgCJs7y2NbtBm7xiWii_w2p-PrVTiR042kpj53ghuJJWwXw_jaoLY&s',
#       'width': '318',
#       'height': '159'}],
#     'metatags': [{'msapplication-tilecolor': '#603cba',
#       'og:image': 'https://gypa.org/GYPA-OG-Image.png',
#       'theme-color': '#ffffff',
#       'og:image:width': '1200',
#       'og:type': 'website',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Greater Yuma Port Authority',
#       'og:title': 'Greater Yuma Port Authority',
#       'og:image:height': '630',
#       'og:description': 'The Greater Yuma Port Authority is the lead agency for developing a gateway for global trade and facilitating multi-modal transportation and trade opportunities with the San Luis II commercial port of entry border crossing.',
#       'twitter:image:alt': 'Greater Yuma Port Authority',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no',
#       'og:url': 'https://gypa.org/articles.html'}],
#     'cse_image': [{'src': 'https://gypa.org/GYPA-OG-Image.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Untitled',
#    'htmlTitle': 'Untitled',
#    'link': 'https://caleprocure.ca.gov/PD/Events',
#    'displayLink': 'caleprocure.ca.gov',
#    'snippet': 'Poly View Drive, San Luis Obispo, CA 93405. Create connections across the CSU ... Doing Business with the U.S. General Services Administration (GSA).',
#    'htmlSnippet': 'Poly View Drive, <b>San Luis</b> Obispo, CA 93405. Create connections across the CSU ... Doing Business with the U.S. <b>General Services Administration</b> (GSA).',
#    'formattedUrl': 'https://caleprocure.ca.gov/PD/Events',
#    'htmlFormattedUrl': 'https://caleprocure.ca.gov/PD/Events',
#    'pagemap': {'hcalendar': [{'summary': '4th Annual Small Business Success Summit',
#       'description': 'Outreach',
#       'dtstart_time': '08:53',
#       'dtstart': '2024-07-27'},
#      {'summary': 'California State University Small Business Expo',
#       'description': 'Outreach',
#       'dtstart_time': '10:11',
#       'dtstart': '2024-07-30'},
#      {'summary': 'Prepare for the Fair',
#       'description': 'Outreach',
#       'dtstart_time': '11:28',
#       'dtstart': '2024-07-30'},
#      {'summary': 'The ABCs of Environmentally Preferable Purchasing for SB/DVBEs',
#       'description': 'Training',
#       'dtstart_time': '08:40',
#       'dtstart': '2024-08-08'},
#      {'summary': 'Doing Business with the U.S. General Services Administration (GSA)',
#       'description': 'Outreach',
#       'dtstart_time': '10:05',
#       'dtstart': '2024-08-13'},
#      {'summary': 'Caltrans North Region Government Contracting Opportunities',
#       'description': 'Outreach',
#       'dtstart_time': '11:09',
#       'dtstart': '2024-08-13'},
#      {'summary': '20th Annual Procurement Resource Fair-8-14-24',
#       'description': 'Outreach',
#       'dtstart_time': '10:18',
#       'dtstart': '2024-08-14'},
#      {'summary': 'Contracting with California State Government',
#       'description': 'Outreach',
#       'dtstart_time': '10:19',
#       'dtstart': '2024-08-15'},
#      {'summary': 'California Hispanic Chamber of Commerce 45th Annual Statewide Convention',
#       'description': 'Outreach',
#       'dtstart_time': '11:40',
#       'dtstart': '2024-08-21'},
#      {'summary': 'Small Business Construction Expo',
#       'description': 'Outreach',
#       'dtstart_time': '08:49',
#       'dtstart': '2024-08-23'},
#      {'summary': 'Small Business Advisory Council Meeting',
#       'description': 'Outreach',
#       'dtstart_time': '06:47',
#       'dtstart': '2024-09-04'},
#      {'summary': 'Solving the Marketing Mystery: the 5Ws - Session 1',
#       'description': 'Training',
#       'dtstart_time': '08:11',
#       'dtstart': '2024-12-05'}],
#     'event': [{'summary': '4th Annual Small Business Success Summit',
#       'location': '2251 Florin Road Sacramento, CA 95822',
#       'dtstart': '2024-07-27'},
#      {'name': '4th Annual Small Business Success Summit',
#       'about': 'Building a better business model.',
#       'description': 'Outreach',
#       'location': '2251 Florin Road Sacramento, CA 95822',
#       'startdate': '2024-07-27T08:53'},
#      {'name': 'California State University Small Business Expo',
#       'about': 'Create connections across the CSU system',
#       'description': 'Outreach',
#       'location': 'Julian A. McPhee University Union, S. Poly View Drive, San Luis Obispo, CA 93405',
#       'startdate': '2024-07-30T10:11'},
#      {'name': 'Prepare for the Fair',
#       'about': 'Gain the knowledge necessary to do business with Caltrans and government buyers',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-07-30T11:28'},
#      {'name': 'The ABCs of Environmentally Preferable Purchasing for SB/DVBEs',
#       'about': 'Did you know as a business selling to the state of California, there are Environmentally Preferable Purchasing requirements in some solicitations?',
#       'description': 'Training',
#       'location': 'Virtual',
#       'startdate': '2024-08-08T08:40'},
#      {'name': 'Doing Business with the U.S. General Services Administration (GSA)',
#       'about': 'Get your piece of the $84 billion the GSA purchases.',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-08-13T10:05'},
#      {'name': 'Caltrans North Region Government Contracting Opportunities',
#       'about': 'Network with resource partner agencies.',
#       'description': 'Outreach',
#       'location': 'Online',
#       'startdate': '2024-08-13T11:09'},
#      {'name': '20th Annual Procurement Resource Fair-8-14-24',
#       'about': 'Get your business ready for government contracting.',
#       'description': 'Outreach',
#       'location': 'Caltrans District 11 Office, 4050 Taylor Street, San Diego, CA 92110',
#       'startdate': '2024-08-14T10:18'},
#      {'name': 'Contracting with California State Government',
#       'about': 'Discover the state’s procurement methods to grow your business',
#       'description': 'Outreach',
#       'location': 'online',
#       'startdate': '2024-08-15T10:19'},
#      {'name': 'California Hispanic Chamber of Commerce 45th Annual Statewide Convention',
#       'about': 'Be inspired and champion your growth, innovation, and empowerment.',
#       'description': 'Outreach',
#       'location': 'Bakersfield Marriott at the Convention Center, 801 Truxtun Ave., Bakersfield, CA 93301',
#       'startdate': '2024-08-21T11:40'},
#      {'name': 'Small Business Construction Expo',
#       'about': 'Build your network. Grow your business.',
#       'description': 'Outreach',
#       'location': 'Long Beach Convention Center 300 E. Ocean Blvd Long Beach, CA 90802',
#       'startdate': '2024-08-23T08:49'},
#      {'name': 'Small Business Advisory Council Meeting',
#       'about': 'A forum for representatives of the California small business community to provide input on policies and practices.',
#       'description': 'Outreach',
#       'location': 'DGS Ziggurat Building- 707 Third Street, West Sacramento, CA 95605 from 1 to 4 p.m.',
#       'startdate': '2024-09-04T06:47'},
#      {'name': 'Solving the Marketing Mystery: the 5Ws - Session 1',
#       'about': 'Solve the Marketing Mystery of state procurement by utilizing the 5Ws: Why, What, Where, Who and When.',
#       'description': 'Training',
#       'location': 'Virtual',
#       'startdate': '2024-12-05T08:11'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Embodied Carbon & Whole Building Life Cycle Assessment ...',
#    'htmlTitle': 'Embodied Carbon &amp; Whole Building Life Cycle Assessment ...',
#    'link': 'https://brightworks.net/practice-area/embodied-carbon-life-cycle-assessment/',
#    'displayLink': 'brightworks.net',
#    'snippet': 'U.S. General Services Administration (GSA). San Luis Land Port of Entry (LPOE). San Luis, AZ. Brightworks is serving as sustainability consultant for the major\xa0...',
#    'htmlSnippet': 'U.S. <b>General Services Administration</b> (GSA). <b>San Luis</b> Land Port of Entry (LPOE). <b>San Luis</b>, AZ. Brightworks is serving as sustainability consultant for the major&nbsp;...',
#    'formattedUrl': 'https://brightworks.net/practice.../embodied-carbon-life-cycle-assessment/',
#    'htmlFormattedUrl': 'https://brightworks.net/practice.../embodied-carbon-life-cycle-assessment/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEC1yPDJh_LmAUF5zzaEfPQvY_YdnQCA3jsQFggos1m405U9wAjvwyJS4&s',
#       'width': '274',
#       'height': '184'}],
#     'metatags': [{'og:image': 'https://brightworks.net/wp-content/uploads/2023/02/Brightworks-Thumbnail.jpg',
#       'og:type': 'article',
#       'og:image:width': '1600',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Brightworks Sustainability',
#       'og:title': 'Embodied Carbon & Whole Building Life Cycle Assessment - Brightworks Sustainability',
#       'og:image:height': '1072',
#       'og:image:type': 'image/jpeg',
#       'msapplication-tileimage': 'https://brightworks.net/wp-content/uploads/2023/03/favicon.ico',
#       'og:description': "Brightworks Sustainability's embodied carbon & life cycle assessment services are important tools in emissions reduction.",
#       'article:modified_time': '2024-04-09T00:08:48+00:00',
#       'viewport': 'width=device-width, initial-scale=1',
#       'og:locale': 'en_US',
#       'og:url': 'https://brightworks.net/practice-area/embodied-carbon-life-cycle-assessment/'}],
#     'cse_image': [{'src': 'https://brightworks.net/wp-content/uploads/2023/02/Brightworks-Thumbnail.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'San Luis Land Port of Entry | Gruen Associates',
#    'htmlTitle': '<b>San Luis</b> Land Port of Entry | Gruen Associates',
#    'link': 'https://www.gruenassociates.com/project/san-luis-land-port-of-entry/',
#    'displayLink': 'www.gruenassociates.com',
#    'snippet': 'With the Federal General Services Administration San Luis Master Plan as the foundation, our team is committed to achieving the fundamental goals of\xa0...',
#    'htmlSnippet': 'With the Federal <b>General Services Administration San Luis</b> Master Plan as the foundation, our team is committed to achieving the fundamental goals of&nbsp;...',
#    'formattedUrl': 'https://www.gruenassociates.com/project/san-luis-land-port-of-entry/',
#    'htmlFormattedUrl': 'https://www.gruenassociates.com/project/<b>san-luis</b>-land-port-of-entry/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQb29WumyYsUc4-O1lYuskS2uHnvZtB2TxNFK6fx9lKm9lTEnl9jTKM0E0&s',
#       'width': '267',
#       'height': '189'}],
#     'metatags': [{'viewport': 'width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0',
#       'msapplication-tileimage': 'https://www.gruenassociates.com/wp-content/uploads/cropped-favicon-270x270.jpg'}],
#     'cse_image': [{'src': 'https://www.gruenassociates.com/wp-content/uploads/SLLPOE-03-400x284.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'San Luis 1 Land Port of Entry North Annex Building - Concord ...',
#    'htmlTitle': '<b>San Luis</b> 1 Land Port of Entry North Annex Building - Concord ...',
#    'link': 'https://concordinc.com/portfolio-posts/san-luis-1/',
#    'displayLink': 'concordinc.com',
#    'snippet': 'LOCATION San Luis, AZ ; SQUARE FOOTAGE 8,200 ; OWNER General Services Administration ; ARCHITECT Jones Studio, Inc.',
#    'htmlSnippet': 'LOCATION <b>San Luis</b>, AZ ; SQUARE FOOTAGE 8,200 ; OWNER <b>General Services Administration</b> ; ARCHITECT Jones Studio, Inc.',
#    'formattedUrl': 'https://concordinc.com/portfolio-posts/san-luis-1/',
#    'htmlFormattedUrl': 'https://concordinc.com/portfolio-posts/<b>san-luis</b>-1/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRormiNxwYP87pa5yx6Em1Blve0Bd1_azl0GoJUe_fM__4andSh1UMBoU1w&s',
#       'width': '225',
#       'height': '225'}],
#     'metatags': [{'og:image': 'https://concordinc.com/wp-content/uploads/2018/09/sanluis414.jpg',
#       'og:type': 'article',
#       'og:image:width': '414',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Concord General Contracting',
#       'og:title': 'San Luis 1 Land Port of Entry North Annex Building - Concord General Contracting',
#       'og:image:height': '414',
#       'twitter:label1': 'Est. reading time',
#       'og:image:type': 'image/jpeg',
#       'twitter:data1': '1 minute',
#       'article:modified_time': '2019-10-29T16:00:22+00:00',
#       'viewport': 'width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0',
#       'og:locale': 'en_US',
#       'og:url': 'https://concordinc.com/portfolio-posts/san-luis-1/',
#       'format-detection': 'telephone=no'}],
#     'webpage': [{'image': 'https://concordinc.com/wp-content/uploads/2018/07/tcc-3_crop-2-150x150.jpg'}],
#     'cse_image': [{'src': 'https://concordinc.com/wp-content/uploads/2018/09/sanluis414.jpg'}],
#     'blog': [{'mainentityofpage': 'San Luis 1 Land Port of Entry North Annex Building LOCATION San Luis, AZ SQUARE FOOTAGE 8,200 OWNER General Services Administration ARCHITECT Jones Studio, Inc. PROJECT HIGHLIGHTS Design Build...'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'GSA, CBP Celebrate Opening Of New POV Lanes At San Luis I ...',
#    'htmlTitle': 'GSA, CBP Celebrate Opening Of New POV Lanes At <b>San Luis</b> I ...',
#    'link': 'https://www.cbp.gov/newsroom/local-media-release/gsa-cbp-celebrate-opening-new-pov-lanes-san-luis-i-landport-entry',
#    'displayLink': 'www.cbp.gov',
#    'snippet': 'Sep 6, 2012 ... San Luis, Ariz. - Today, the U.S. General Services Administration (GSA), U.S. Customs and Border Protection (CBP), and City of San Luis\xa0...',
#    'htmlSnippet': 'Sep 6, 2012 <b>...</b> <b>San Luis</b>, Ariz. - Today, the U.S. <b>General Services Administration</b> (GSA), U.S. Customs and Border Protection (CBP), and City of <b>San Luis</b>&nbsp;...',
#    'formattedUrl': 'https://www.cbp.gov/.../gsa-cbp-celebrate-opening-new-pov-lanes-san-luis-...',
#    'htmlFormattedUrl': 'https://www.cbp.gov/.../gsa-cbp-celebrate-opening-new-pov-lanes-<b>san-luis</b>-...',
#    'pagemap': {'metatags': [{'og:type': 'website',
#       'twitter:card': 'summary',
#       'twitter:title': 'GSA, CBP Celebrate Opening Of New POV Lanes At San Luis I Landport Of Entry',
#       'og:site_name': 'U.S. Customs and Border Protection',
#       'og:image:url': 'https://www.cbp.gov/sites/default/files/cbp-seal-1200-630-px-2021.jpg',
#       'handheldfriendly': 'true',
#       'og:title': 'GSA, CBP Celebrate Opening Of New POV Lanes At San Luis I Landport Of Entry',
#       'og:description': "Securing America's Borders",
#       'twitter:image': 'https://www.cbp.gov/sites/default/files/cbp-seal-vertical-blue_twitter-card_600.jpg',
#       'twitter:site': '@CBP',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'San Luis, Ariz. - Today, the U.S. General Services Administration (GSA), U.S. Customs and Border Protection (CBP), and City of San Luis celebrated the construction of two additional northbound lanes for privately owned vehicles traveling into the United States at the San Luis I Land Port of Entry.',
#       'mobileoptimized': 'width',
#       'og:url': 'https://www.cbp.gov/newsroom/local-media-release/gsa-cbp-celebrate-opening-new-pov-lanes-san-luis-i-landport-entry'}]}}]]

# %%
next_res = service.cse().list(q='"Fort Fairfield" AND "LPOE"', cx=my_cse_id, num=10, start=res['queries']['nextPage'][0]['startIndex'],).execute()
for item in next_res['items']:
        url_items.append(item)
    page += 1
    
    if page == max_page:
        return url_items
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - "Fort Fairfield" AND "LPOE"',
#     'totalResults': '35',
#     'searchTerms': '"Fort Fairfield" AND "LPOE"',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'e5163efc431954d8f'}],
#   'nextPage': [{'title': 'Google Custom Search - "Fort Fairfield" AND "LPOE"',
#     'totalResults': '35',
#     'searchTerms': '"Fort Fairfield" AND "LPOE"',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'e5163efc431954d8f'}]},
#  'context': {'title': 'MSG-project'},
#  'searchInformation': {'searchTime': 0.181649,
#   'formattedSearchTime': '0.18',
#   'totalResults': '35',
#   'formattedTotalResults': '35'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Fort Fairfield Land Port of Entry, Maine | GSA',
#    'htmlTitle': '<b>Fort Fairfield</b> Land Port of Entry, Maine | GSA',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine',
#    'displayLink': 'www.gsa.gov',
#    'snippet': '7 days ago ... This project will deliver a new land port complex to supplement the existing LPOE in Fort Fairfield, Maine. Programming for the new LPOE\xa0...',
#    'htmlSnippet': '7 days ago <b>...</b> This project will deliver a new land port complex to supplement the existing <b>LPOE</b> in <b>Fort Fairfield</b>, Maine. Programming for the new <b>LPOE</b>&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/about.../fort-fairfield-land-port-of-entry-maine',
#    'htmlFormattedUrl': 'https://www.gsa.gov/about.../<b>fort-fairfield</b>-land-port-of-entry-maine',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'Fort Fairfield Land Port of Entry, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'R1',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine',
#       'og:description': 'The Fort Fairfield Land Port of Entry modernization project will help Customs and Border Protection to more efficiently carry out its agency mission at the international border crossing between Fort Fairfield, Maine, and Carlingford, New Brunswick.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Land Ports of Entry Hours of Operation',
#    'htmlTitle': 'Land Ports of Entry Hours of Operation',
#    'link': 'https://www.dhs.gov/sites/default/files/2024-03/2024_0116_cbp_land_ports_of_entry_hours_of_operation.pdf',
#    'displayLink': 'www.dhs.gov',
#    'snippet': 'Jan 16, 2024 ... north of the LPOE that allows vehicles to circumvent inspection. ... Fort Fairfield, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24\xa0...',
#    'htmlSnippet': 'Jan 16, 2024 <b>...</b> north of the <b>LPOE</b> that allows vehicles to circumvent inspection. ... <b>Fort Fairfield</b>, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24&nbsp;...',
#    'formattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...',
#    'htmlFormattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz0cB8j2A5sEyWvJfIkx8pH0kr4nSs9hvhPKUpaPG-Bu74GGgi75UrTJ-L&s',
#       'width': '199',
#       'height': '253'}],
#     'metatags': [{'moddate': "D:20240301152537-05'00'",
#       'creationdate': "D:20240116100530-05'00'",
#       'creator': 'Adobe Acrobat Pro (64-bit) 23.6.20380',
#       'author': 'CBP',
#       'subject': 'CBP Land Ports of Entry Hours of Operation',
#       'producer': 'Adobe Acrobat Pro (64-bit) 23.6.20380',
#       'title': 'Land Ports of Entry Hours of Operation'}],
#     'cse_image': [{'src': 'x-raw-image:///2da3e8d4a7572571d0b7b49b0a5e6c9e5dc1011f66b819290ab9ce66d1636dfa'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'R1 LPOE External Fact Sheet/Leave-Behind',
#    'htmlTitle': 'R1 <b>LPOE</b> External Fact Sheet/Leave-Behind',
#    'link': 'https://www.gsa.gov/system/files/Fort%20Fairfield%20update%20oct%202023.pdf',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'This project will deliver a new Land Port of Entry (LPOE) complex to supplement the existing LPOE in Fort ... Border crossing station in Fort Fairfield, Maine.',
#    'htmlSnippet': 'This project will deliver a new Land Port of Entry (<b>LPOE</b>) complex to supplement the existing <b>LPOE</b> in Fort ... Border crossing station in <b>Fort Fairfield</b>, Maine.',
#    'formattedUrl': 'https://www.gsa.gov/.../Fort%20Fairfield%20update%20oct%202023.pdf',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../Fort%20Fairfield%20update%20oct%202023.pdf',
#    'pagemap': {'metatags': [{'moddate': "D:20231023100455-04'00'",
#       'creationdate': "D:20231023093827-04'00'",
#       'creator': 'Google',
#       'title': 'R1 LPOE External Fact Sheet/Leave-Behind'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'Search Government Contracts for Bid in Aroostook County (ME ...',
#    'htmlTitle': 'Search Government Contracts for Bid in Aroostook County (ME ...',
#    'link': 'https://iq.govwin.com/neo/public/pop/Aroostook%20County%20%28ME%29',
#    'displayLink': 'iq.govwin.com',
#    'snippet': 'Construction Manager as Constructor (CMc) Services for two (2) U.S. Customs and Border Protection (CBP) Land Ports of Entry (LPOE) - in Fort Fairfield, ME, and\xa0...',
#    'htmlSnippet': 'Construction Manager as Constructor (CMc) Services for two (2) U.S. Customs and Border Protection (CBP) Land Ports of Entry (<b>LPOE</b>) - in <b>Fort Fairfield</b>, ME, and&nbsp;...',
#    'formattedUrl': 'https://iq.govwin.com/neo/public/.../Aroostook%20County%20%28ME%2...',
#    'htmlFormattedUrl': 'https://iq.govwin.com/neo/public/.../Aroostook%20County%20%28ME%2...',
#    'pagemap': {'metatags': [{'viewport': 'width=device-width, initial-scale=1'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'U.S. General Services Administration to host public scoping meeting ...',
#    'htmlTitle': 'U.S. General Services Administration to host public scoping meeting ...',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/region-1-newsroom/press-releases/us-general-services-administration-to-host-publi-07222024',
#    'displayLink': 'www.gsa.gov',
#    'snippet': '7 days ago ... ... Fort Fairfield, Maine ... Fort Fairfield LPOE EA” in the subject line. Mail: Send written\xa0...',
#    'htmlSnippet': '7 days ago <b>...</b> ... Fort Fairfield, Maine ... <b>Fort Fairfield LPOE</b> EA” in the subject line. Mail: Send written&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/.../us-general-services-administration-to-host-publi-07...',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../us-general-services-administration-to-host-publi-07...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'U.S. General Services Administration to host public scoping meeting for the Land Port of Entry project in Fort Fairfield, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'OSC',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/region-1-newsroom/press-releases/us-general-services-administration-to-host-publi-07222024',
#       'og:description': 'BOSTON – In compliance with the National Environmental Policy Act, the U.S. General Services Administration (GSA) will host a public meeting in support of an Environmental Assessment for the proposed modernization and expansion project of the Land Port of Entry at Fort Fairfield, Maine.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Facilities Support Group',
#    'htmlTitle': 'Facilities Support Group',
#    'link': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'displayLink': 'www.highergov.com',
#    'snippet': '... LPOE, AND MILLTOWN (ME0091ZZ) LPOE, MAINE, MODIFIED TO INCLUDE COVID-19 ... FORT FAIRFIELD (ME0601BF) LPOE, PRESQUE ISLE (ME0078ZZ) SSA, HOULTON\xa0...',
#    'htmlSnippet': '... <b>LPOE</b>, AND MILLTOWN (ME0091ZZ) <b>LPOE</b>, MAINE, MODIFIED TO INCLUDE COVID-19 ... <b>FORT FAIRFIELD</b> (ME0601BF) <b>LPOE</b>, PRESQUE ISLE (ME0078ZZ) SSA, HOULTON&nbsp;...',
#    'formattedUrl': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'htmlFormattedUrl': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'pagemap': {'metatags': [{'application-name': 'HigherGov',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Calais Ferry Point Land Port of Entry, Maine | GSA',
#    'htmlTitle': 'Calais Ferry Point Land Port of Entry, Maine | GSA',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/calais-ferry-point-land-port-of-entry-maine',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'LPOE details. Fact sheet: Calais Ferry Point LPOE fact sheet [PDF - 178 KB] ... Fort Fairfield Land Port of Entry, Maine · Hartford Courthouse · Highgate\xa0...',
#    'htmlSnippet': '<b>LPOE</b> details. Fact sheet: Calais Ferry Point <b>LPOE</b> fact sheet [PDF - 178 KB] ... <b>Fort Fairfield</b> Land Port of Entry, Maine &middot; Hartford Courthouse &middot; Highgate&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/...1.../calais-ferry-point-land-port-of-entry-maine',
#    'htmlFormattedUrl': 'https://www.gsa.gov/...1.../calais-ferry-point-land-port-of-entry-maine',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'Calais Ferry Point Land Port of Entry, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'R1',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/calais-ferry-point-land-port-of-entry-maine',
#       'og:description': 'The Calais Ferry Point Land port of Entry, Maine modernization project will help Customs and Border Protection to more efficiently carry out its agency mission at the international border crossing between Calais, Maine, and Saint Stephen, New Brunswick.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'ebtc annual report 2023',
#    'htmlTitle': 'ebtc annual report 2023',
#    'link': 'https://ebtc.info/wp-content/uploads/2024/03/EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'displayLink': 'ebtc.info',
#    'snippet': 'FORT FAIRFIELD, ME LAND PORT OF ENTRY (LPOE). The design and construction of a new $41.5 million LPOE in Fort Fairfield, Maine will replace the existing\xa0...',
#    'htmlSnippet': '<b>FORT FAIRFIELD</b>, ME LAND PORT OF ENTRY (<b>LPOE</b>). The design and construction of a new $41.5 million <b>LPOE</b> in <b>Fort Fairfield</b>, Maine will replace the existing&nbsp;...',
#    'formattedUrl': 'https://ebtc.info/wp-content/.../EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'htmlFormattedUrl': 'https://ebtc.info/wp-content/.../EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT3e7Sv0me_FVgpHPktsXL4UujMOBq9Q2lj8iXpxQvLqqg3_1Fy2q_DA_LO&s',
#       'width': '235',
#       'height': '215'}],
#     'metatags': [{'moddate': "D:20240328102346-03'00'",
#       'creator': 'Microsoft® Word for Microsoft 365',
#       'creationdate': "D:20240328102346-03'00'",
#       'author': 'Microsoft Office User',
#       'producer': 'Microsoft® Word for Microsoft 365'}],
#     'cse_image': [{'src': 'x-raw-image:///43479fdab91214ec5d5551892d7f91e83e0f9cdbc1042b7c2653680bbbeb63fa'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'General Services Administration (GSA) Green Building Lifecycle ...',
#    'htmlTitle': 'General Services Administration (GSA) Green Building Lifecycle ...',
#    'link': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'displayLink': 'www.governmentattic.org',
#    'snippet': 'Oct 4, 2021 ... LPOE, FORT FAIRFIELD. 1 BOUNDRY LINE RD. FORT FAIRFIELD. ME. 04742-3628. 1934 2. National Register. Listed. 01. ME0701. Federally. Owned.',
#    'htmlSnippet': 'Oct 4, 2021 <b>...</b> <b>LPOE</b>, <b>FORT FAIRFIELD</b>. 1 BOUNDRY LINE RD. <b>FORT FAIRFIELD</b>. ME. 04742-3628. 1934 2. National Register. Listed. 01. ME0701. Federally. Owned.',
#    'formattedUrl': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'htmlFormattedUrl': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBRHLjCdrtX14Qf26a2DUK08gAXlMR0Bbi5G0sHnW3Vna9gqdNoXiVSvc&s',
#       'width': '197',
#       'height': '255'}],
#     'metatags': [{'moddate': "D:20210927084236-07'00'",
#       'creationdate': "D:20210924181420-07'00'",
#       'creator': 'Acrobat PDFMaker 17 for Excel',
#       'esri_workbook_id': 'c60ca02ac11e404abf866df832b45993',
#       'author': 'GSA / governmentattic.org',
#       'subject': 'General Services Administration (GSA) Green Building Lifecycle Upgrade Database (gBuild) 2020',
#       'producer': 'Adobe PDF Library 17.11.238',
#       'title': 'General Services Administration (GSA) Green Building Lifecycle Upgrade Database (gBuild) 2020'}],
#     'cse_image': [{'src': 'x-raw-image:///b1540ae2c5bc1eb2b88b85192d5ac9f0ee5e6c2934c0c43b27e3ee1aea0da6e0'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'Facilities Support Group, LLC Details',
#    'htmlTitle': 'Facilities Support Group, LLC Details',
#    'link': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'displayLink': 'govtribe.com',
#    'snippet': 'Jul 15, 2024 ... This BPA covers combined facility engineering, operations, maintenance, and janitorial services at 15 LPOE locations across northern Maine.',
#    'htmlSnippet': 'Jul 15, 2024 <b>...</b> This BPA covers combined facility engineering, operations, maintenance, and janitorial services at 15 <b>LPOE</b> locations across northern Maine.',
#    'formattedUrl': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'htmlFormattedUrl': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbsymt_gWYj99Y51YQhkvIz-NXd3ZcfY2VZ_8oZdY40RUzV33a3tmhVRIY&s',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'application-name': 'GovTribe',
#       'msapplication-tilecolor': '#FFFFFF',
#       'og:image': 'https://govtribe.com/img/logo/og_logo.png',
#       'og:type': 'website',
#       'og:image:width': '1600',
#       'og:image:alt': 'GovTribe Logo',
#       'twitter:card': 'summary',
#       'twitter:title': 'Facilities Support Group, LLC',
#       'og:title': 'Facilities Support Group, LLC',
#       'og:image:height': '900',
#       'og:image:type': 'image/png',
#       'msapplication-tileimage': 'zmstile-144x144.png',
#       'og:description': 'Facilities Support Group, LLC is a small business and SBA-certified HUBZone firm that provides facility management, operations, maintenance, and engineering...',
#       'twitter:image': 'https://govtribe.com/img/logo/150.png?size=250',
#       'twitter:image:alt': 'Facilities Support Group, LLC Logo',
#       'twitter:site': '@govtribe',
#       'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no',
#       'twitter:description': 'Facilities Support Group, LLC is a small business and SBA-certified HUBZone firm that provides facility management, operations, maintenance, and engineering...',
#       'csrf-token': 'qPqCxh3fkb0uBhBOibmaZQjcnLyFKmupFFz6qBVS',
#       'og:url': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9'}],
#     'cse_image': [{'src': 'https://govtribe.com/img/logo/og_logo.png'}]}}]}

# %%
res['queries']['nextPage'][0]['startIndex']
# Out:
# 11

# %%
res
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - "Fort Fairfield" AND "LPOE"',
#     'totalResults': '35',
#     'searchTerms': '"Fort Fairfield" AND "LPOE"',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'e5163efc431954d8f'}],
#   'nextPage': [{'title': 'Google Custom Search - "Fort Fairfield" AND "LPOE"',
#     'totalResults': '35',
#     'searchTerms': '"Fort Fairfield" AND "LPOE"',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'e5163efc431954d8f'}]},
#  'context': {'title': 'MSG-project'},
#  'searchInformation': {'searchTime': 0.181649,
#   'formattedSearchTime': '0.18',
#   'totalResults': '35',
#   'formattedTotalResults': '35'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Fort Fairfield Land Port of Entry, Maine | GSA',
#    'htmlTitle': '<b>Fort Fairfield</b> Land Port of Entry, Maine | GSA',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine',
#    'displayLink': 'www.gsa.gov',
#    'snippet': '7 days ago ... This project will deliver a new land port complex to supplement the existing LPOE in Fort Fairfield, Maine. Programming for the new LPOE\xa0...',
#    'htmlSnippet': '7 days ago <b>...</b> This project will deliver a new land port complex to supplement the existing <b>LPOE</b> in <b>Fort Fairfield</b>, Maine. Programming for the new <b>LPOE</b>&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/about.../fort-fairfield-land-port-of-entry-maine',
#    'htmlFormattedUrl': 'https://www.gsa.gov/about.../<b>fort-fairfield</b>-land-port-of-entry-maine',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'Fort Fairfield Land Port of Entry, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'R1',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/fort-fairfield-land-port-of-entry-maine',
#       'og:description': 'The Fort Fairfield Land Port of Entry modernization project will help Customs and Border Protection to more efficiently carry out its agency mission at the international border crossing between Fort Fairfield, Maine, and Carlingford, New Brunswick.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Land Ports of Entry Hours of Operation',
#    'htmlTitle': 'Land Ports of Entry Hours of Operation',
#    'link': 'https://www.dhs.gov/sites/default/files/2024-03/2024_0116_cbp_land_ports_of_entry_hours_of_operation.pdf',
#    'displayLink': 'www.dhs.gov',
#    'snippet': 'Jan 16, 2024 ... north of the LPOE that allows vehicles to circumvent inspection. ... Fort Fairfield, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24\xa0...',
#    'htmlSnippet': 'Jan 16, 2024 <b>...</b> north of the <b>LPOE</b> that allows vehicles to circumvent inspection. ... <b>Fort Fairfield</b>, Maine. 24 hours / 7 days. Boston. Fort Kent, Maine. 24&nbsp;...',
#    'formattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...',
#    'htmlFormattedUrl': 'https://www.dhs.gov/.../2024_0116_cbp_land_ports_of_entry_hours_of_o...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz0cB8j2A5sEyWvJfIkx8pH0kr4nSs9hvhPKUpaPG-Bu74GGgi75UrTJ-L&s',
#       'width': '199',
#       'height': '253'}],
#     'metatags': [{'moddate': "D:20240301152537-05'00'",
#       'creationdate': "D:20240116100530-05'00'",
#       'creator': 'Adobe Acrobat Pro (64-bit) 23.6.20380',
#       'author': 'CBP',
#       'subject': 'CBP Land Ports of Entry Hours of Operation',
#       'producer': 'Adobe Acrobat Pro (64-bit) 23.6.20380',
#       'title': 'Land Ports of Entry Hours of Operation'}],
#     'cse_image': [{'src': 'x-raw-image:///2da3e8d4a7572571d0b7b49b0a5e6c9e5dc1011f66b819290ab9ce66d1636dfa'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'R1 LPOE External Fact Sheet/Leave-Behind',
#    'htmlTitle': 'R1 <b>LPOE</b> External Fact Sheet/Leave-Behind',
#    'link': 'https://www.gsa.gov/system/files/Fort%20Fairfield%20update%20oct%202023.pdf',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'This project will deliver a new Land Port of Entry (LPOE) complex to supplement the existing LPOE in Fort ... Border crossing station in Fort Fairfield, Maine.',
#    'htmlSnippet': 'This project will deliver a new Land Port of Entry (<b>LPOE</b>) complex to supplement the existing <b>LPOE</b> in Fort ... Border crossing station in <b>Fort Fairfield</b>, Maine.',
#    'formattedUrl': 'https://www.gsa.gov/.../Fort%20Fairfield%20update%20oct%202023.pdf',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../Fort%20Fairfield%20update%20oct%202023.pdf',
#    'pagemap': {'metatags': [{'moddate': "D:20231023100455-04'00'",
#       'creationdate': "D:20231023093827-04'00'",
#       'creator': 'Google',
#       'title': 'R1 LPOE External Fact Sheet/Leave-Behind'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'Search Government Contracts for Bid in Aroostook County (ME ...',
#    'htmlTitle': 'Search Government Contracts for Bid in Aroostook County (ME ...',
#    'link': 'https://iq.govwin.com/neo/public/pop/Aroostook%20County%20%28ME%29',
#    'displayLink': 'iq.govwin.com',
#    'snippet': 'Construction Manager as Constructor (CMc) Services for two (2) U.S. Customs and Border Protection (CBP) Land Ports of Entry (LPOE) - in Fort Fairfield, ME, and\xa0...',
#    'htmlSnippet': 'Construction Manager as Constructor (CMc) Services for two (2) U.S. Customs and Border Protection (CBP) Land Ports of Entry (<b>LPOE</b>) - in <b>Fort Fairfield</b>, ME, and&nbsp;...',
#    'formattedUrl': 'https://iq.govwin.com/neo/public/.../Aroostook%20County%20%28ME%2...',
#    'htmlFormattedUrl': 'https://iq.govwin.com/neo/public/.../Aroostook%20County%20%28ME%2...',
#    'pagemap': {'metatags': [{'viewport': 'width=device-width, initial-scale=1'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'U.S. General Services Administration to host public scoping meeting ...',
#    'htmlTitle': 'U.S. General Services Administration to host public scoping meeting ...',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/region-1-newsroom/press-releases/us-general-services-administration-to-host-publi-07222024',
#    'displayLink': 'www.gsa.gov',
#    'snippet': '7 days ago ... ... Fort Fairfield, Maine ... Fort Fairfield LPOE EA” in the subject line. Mail: Send written\xa0...',
#    'htmlSnippet': '7 days ago <b>...</b> ... Fort Fairfield, Maine ... <b>Fort Fairfield LPOE</b> EA” in the subject line. Mail: Send written&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/.../us-general-services-administration-to-host-publi-07...',
#    'htmlFormattedUrl': 'https://www.gsa.gov/.../us-general-services-administration-to-host-publi-07...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'U.S. General Services Administration to host public scoping meeting for the Land Port of Entry project in Fort Fairfield, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'OSC',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/region-1-newsroom/press-releases/us-general-services-administration-to-host-publi-07222024',
#       'og:description': 'BOSTON – In compliance with the National Environmental Policy Act, the U.S. General Services Administration (GSA) will host a public meeting in support of an Environmental Assessment for the proposed modernization and expansion project of the Land Port of Entry at Fort Fairfield, Maine.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Facilities Support Group',
#    'htmlTitle': 'Facilities Support Group',
#    'link': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'displayLink': 'www.highergov.com',
#    'snippet': '... LPOE, AND MILLTOWN (ME0091ZZ) LPOE, MAINE, MODIFIED TO INCLUDE COVID-19 ... FORT FAIRFIELD (ME0601BF) LPOE, PRESQUE ISLE (ME0078ZZ) SSA, HOULTON\xa0...',
#    'htmlSnippet': '... <b>LPOE</b>, AND MILLTOWN (ME0091ZZ) <b>LPOE</b>, MAINE, MODIFIED TO INCLUDE COVID-19 ... <b>FORT FAIRFIELD</b> (ME0601BF) <b>LPOE</b>, PRESQUE ISLE (ME0078ZZ) SSA, HOULTON&nbsp;...',
#    'formattedUrl': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'htmlFormattedUrl': 'https://www.highergov.com/awardee/facilities-support-group-llc-10012621/',
#    'pagemap': {'metatags': [{'application-name': 'HigherGov',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Calais Ferry Point Land Port of Entry, Maine | GSA',
#    'htmlTitle': 'Calais Ferry Point Land Port of Entry, Maine | GSA',
#    'link': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/calais-ferry-point-land-port-of-entry-maine',
#    'displayLink': 'www.gsa.gov',
#    'snippet': 'LPOE details. Fact sheet: Calais Ferry Point LPOE fact sheet [PDF - 178 KB] ... Fort Fairfield Land Port of Entry, Maine · Hartford Courthouse · Highgate\xa0...',
#    'htmlSnippet': '<b>LPOE</b> details. Fact sheet: Calais Ferry Point <b>LPOE</b> fact sheet [PDF - 178 KB] ... <b>Fort Fairfield</b> Land Port of Entry, Maine &middot; Hartford Courthouse &middot; Highgate&nbsp;...',
#    'formattedUrl': 'https://www.gsa.gov/...1.../calais-ferry-point-land-port-of-entry-maine',
#    'htmlFormattedUrl': 'https://www.gsa.gov/...1.../calais-ferry-point-land-port-of-entry-maine',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSSUa_90S6WXJo0eHwAmolNNSW0k_edIyja2pnX4f9HGTRgESASH5_EoUw&s',
#       'width': '275',
#       'height': '183'}],
#     'metatags': [{'og:image': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg',
#       'og:type': 'website',
#       'og:image:alt': 'Photo of GSA headquarters',
#       'og:site_name': 'U.S. General Services Administration',
#       'handheldfriendly': 'true',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'og:title': 'Calais Ferry Point Land Port of Entry, Maine',
#       'mobileoptimized': 'width',
#       'organization': 'R1',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.gsa.gov/about-us/gsa-regions/region-1-new-england/buildings-and-facilities/development-projects/calais-ferry-point-land-port-of-entry-maine',
#       'og:description': 'The Calais Ferry Point Land port of Entry, Maine modernization project will help Customs and Border Protection to more efficiently carry out its agency mission at the international border crossing between Calais, Maine, and Saint Stephen, New Brunswick.'}],
#     'cse_image': [{'src': 'https://www.gsa.gov/sites/gsa.gov/themes/custom/gsa/custom_assets/images/open_graph_image.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'ebtc annual report 2023',
#    'htmlTitle': 'ebtc annual report 2023',
#    'link': 'https://ebtc.info/wp-content/uploads/2024/03/EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'displayLink': 'ebtc.info',
#    'snippet': 'FORT FAIRFIELD, ME LAND PORT OF ENTRY (LPOE). The design and construction of a new $41.5 million LPOE in Fort Fairfield, Maine will replace the existing\xa0...',
#    'htmlSnippet': '<b>FORT FAIRFIELD</b>, ME LAND PORT OF ENTRY (<b>LPOE</b>). The design and construction of a new $41.5 million <b>LPOE</b> in <b>Fort Fairfield</b>, Maine will replace the existing&nbsp;...',
#    'formattedUrl': 'https://ebtc.info/wp-content/.../EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'htmlFormattedUrl': 'https://ebtc.info/wp-content/.../EBTC-2023-ANNUAL-REPORT-FINAL.pdf',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT3e7Sv0me_FVgpHPktsXL4UujMOBq9Q2lj8iXpxQvLqqg3_1Fy2q_DA_LO&s',
#       'width': '235',
#       'height': '215'}],
#     'metatags': [{'moddate': "D:20240328102346-03'00'",
#       'creator': 'Microsoft® Word for Microsoft 365',
#       'creationdate': "D:20240328102346-03'00'",
#       'author': 'Microsoft Office User',
#       'producer': 'Microsoft® Word for Microsoft 365'}],
#     'cse_image': [{'src': 'x-raw-image:///43479fdab91214ec5d5551892d7f91e83e0f9cdbc1042b7c2653680bbbeb63fa'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'General Services Administration (GSA) Green Building Lifecycle ...',
#    'htmlTitle': 'General Services Administration (GSA) Green Building Lifecycle ...',
#    'link': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'displayLink': 'www.governmentattic.org',
#    'snippet': 'Oct 4, 2021 ... LPOE, FORT FAIRFIELD. 1 BOUNDRY LINE RD. FORT FAIRFIELD. ME. 04742-3628. 1934 2. National Register. Listed. 01. ME0701. Federally. Owned.',
#    'htmlSnippet': 'Oct 4, 2021 <b>...</b> <b>LPOE</b>, <b>FORT FAIRFIELD</b>. 1 BOUNDRY LINE RD. <b>FORT FAIRFIELD</b>. ME. 04742-3628. 1934 2. National Register. Listed. 01. ME0701. Federally. Owned.',
#    'formattedUrl': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'htmlFormattedUrl': 'https://www.governmentattic.org/42docs/GSAgBuild_2020.pdf',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBRHLjCdrtX14Qf26a2DUK08gAXlMR0Bbi5G0sHnW3Vna9gqdNoXiVSvc&s',
#       'width': '197',
#       'height': '255'}],
#     'metatags': [{'moddate': "D:20210927084236-07'00'",
#       'creationdate': "D:20210924181420-07'00'",
#       'creator': 'Acrobat PDFMaker 17 for Excel',
#       'esri_workbook_id': 'c60ca02ac11e404abf866df832b45993',
#       'author': 'GSA / governmentattic.org',
#       'subject': 'General Services Administration (GSA) Green Building Lifecycle Upgrade Database (gBuild) 2020',
#       'producer': 'Adobe PDF Library 17.11.238',
#       'title': 'General Services Administration (GSA) Green Building Lifecycle Upgrade Database (gBuild) 2020'}],
#     'cse_image': [{'src': 'x-raw-image:///b1540ae2c5bc1eb2b88b85192d5ac9f0ee5e6c2934c0c43b27e3ee1aea0da6e0'}]},
#    'mime': 'application/pdf',
#    'fileFormat': 'PDF/Adobe Acrobat'},
#   {'kind': 'customsearch#result',
#    'title': 'Facilities Support Group, LLC Details',
#    'htmlTitle': 'Facilities Support Group, LLC Details',
#    'link': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'displayLink': 'govtribe.com',
#    'snippet': 'Jul 15, 2024 ... This BPA covers combined facility engineering, operations, maintenance, and janitorial services at 15 LPOE locations across northern Maine.',
#    'htmlSnippet': 'Jul 15, 2024 <b>...</b> This BPA covers combined facility engineering, operations, maintenance, and janitorial services at 15 <b>LPOE</b> locations across northern Maine.',
#    'formattedUrl': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'htmlFormattedUrl': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbsymt_gWYj99Y51YQhkvIz-NXd3ZcfY2VZ_8oZdY40RUzV33a3tmhVRIY&s',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'application-name': 'GovTribe',
#       'msapplication-tilecolor': '#FFFFFF',
#       'og:image': 'https://govtribe.com/img/logo/og_logo.png',
#       'og:type': 'website',
#       'og:image:width': '1600',
#       'og:image:alt': 'GovTribe Logo',
#       'twitter:card': 'summary',
#       'twitter:title': 'Facilities Support Group, LLC',
#       'og:title': 'Facilities Support Group, LLC',
#       'og:image:height': '900',
#       'og:image:type': 'image/png',
#       'msapplication-tileimage': 'zmstile-144x144.png',
#       'og:description': 'Facilities Support Group, LLC is a small business and SBA-certified HUBZone firm that provides facility management, operations, maintenance, and engineering...',
#       'twitter:image': 'https://govtribe.com/img/logo/150.png?size=250',
#       'twitter:image:alt': 'Facilities Support Group, LLC Logo',
#       'twitter:site': '@govtribe',
#       'viewport': 'width=device-width,initial-scale=1,shrink-to-fit=no',
#       'twitter:description': 'Facilities Support Group, LLC is a small business and SBA-certified HUBZone firm that provides facility management, operations, maintenance, and engineering...',
#       'csrf-token': 'qPqCxh3fkb0uBhBOibmaZQjcnLyFKmupFFz6qBVS',
#       'og:url': 'https://govtribe.com/vendors/facilities-support-group-llc-7w3l9'}],
#     'cse_image': [{'src': 'https://govtribe.com/img/logo/og_logo.png'}]}}]}
